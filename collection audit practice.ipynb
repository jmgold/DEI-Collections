# %%
import sqlite3
import pandas as pd
import psycopg2
import configparser
import numpy as np
import os
import re
import time
import nmslib
from scipy.sparse import csr_matrix # may not be required 
from scipy.sparse import rand # may not be required
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
try:
    sqliteConnection = sqlite3.connect('DEI Database.db')
    cursor = sqliteConnection.cursor()
    print("Connected to SQLite")
    
    sql_query = """SELECT Genre,COALESCE(Author,'') AS Author,Title,Year,COALESCE(Author,'')||' '||Title AS match_point
                FROM title_list
                """
    cursor.execute(sql_query)
    sqliteConnection.commit()
    comp_rows = cursor.fetchall()
    cursor.close()
except sqlite3.Error as error:
    print("Failed to run query", error)
# Out:
# Connected to SQLite

# %%
column_names = ["Genre","Author","Title","Year","MatchPoint"]
comp_df = pd.DataFrame(comp_rows, columns=column_names)
comp_df
# Out:
#                        Genre          Author  \
# 0     Romance/Erotic Romance  Charlie Adhara
# 1     Romance/Erotic Romance  Charlie Adhara
# 2     Romance/Erotic Romance  Charlie Adhara
# 3     Romance/Erotic Romance  Charlie Adhara
# 4     Romance/Erotic Romance     Brea Alepoú
# ...                      ...             ...
# 4011     Fiction Anthologies
# 4012     Fiction Anthologies
# 4013     Fiction Anthologies
# 4014     Fiction Anthologies
# 4015     Fiction Anthologies
#
#                                                   Title    Year  \
# 0                                  The Wolf at the Door  2018.0
# 1                                       The Wolf at Bay  2018.0
# 2                                  Thrown to the Wolves  2019.0
# 3                              Wolf in Sheep’s Clothing  2020.0
# 4                                   His Bewildered Mate  2019.0
# ...                                                 ...     ...
# 4011  Shades Of Black: Crime And Mystery Stories By ...  2004.0
# 4012                 Slay: Stories of the Vampire Noire  2020.0
# 4013  Transcendent 3: The Year’s Best Transgender Sp...  2018.0
# 4014                                     Transcendent 4  2019.0
# 4015  Walking the Clouds: An Anthology of Indigenous...  2012.0
#
#                                              MatchPoint
# 0                   Charlie Adhara The Wolf at the Door
# 1                        Charlie Adhara The Wolf at Bay
# 2                   Charlie Adhara Thrown to the Wolves
# 3               Charlie Adhara Wolf in Sheep’s Clothing
# 4                       Brea Alepoú His Bewildered Mate
# ...                                                 ...
# 4011   Shades Of Black: Crime And Mystery Stories By...
# 4012                 Slay: Stories of the Vampire Noire
# 4013   Transcendent 3: The Year’s Best Transgender S...
# 4014                                     Transcendent 4
# 4015   Walking the Clouds: An Anthology of Indigenou...
#
# [4016 rows x 5 columns]

# %%
config = configparser.ConfigParser()
config.read('Y:\\SQL Reports\\creds\\app_SIC.ini')

try:
    query = """SELECT
b.best_title AS title,
COALESCE(REPLACE(SPLIT_PART(SPLIT_PART(b.best_author,' (',1),', ',2),'.','')||' '||SPLIT_PART(b.best_author,', ',1),'') AS author,
b.publish_year,
STRING_AGG(DISTINCT i.location_code,',') AS location,
COALESCE(REPLACE(SPLIT_PART(SPLIT_PART(b.best_author,' (',1),', ',2),'.','')||' '||SPLIT_PART(b.best_author,', ',1),'')||' '||b.best_title AS match_point

FROM
sierra_view.bib_record_property b
JOIN
sierra_view.bib_record_item_record_link l
ON
b.bib_record_id = l.bib_record_id
JOIN
sierra_view.item_record i
ON
l.item_record_id = i.id
AND SUBSTRING(i.location_code,4,1) NOT IN ('y','j')
AND i.location_code ~ '^lin'
JOIN
sierra_view.phrase_entry d
ON
l.bib_record_id = d.record_id AND d.index_tag = 'd' AND d.index_entry ~ 'fiction'
WHERE
b.material_code = 'a'
AND b.publish_year >= 2018

GROUP BY 1,2,3
ORDER BY 1,2
    """
    #variable connection string should be defined in the imported config file
    conn = psycopg2.connect( config['db']['connection_string'] )
except:
    print("unable to connect to the database")
    clear_connection()
cursor = conn.cursor()
cursor.execute(query)
#For now, just storing the data in a variable. We'll use it later.
local_rows = cursor.fetchall()
conn.close()

# %%
column_names_local = ["Title", "Author", "Year", "Location", "MatchPoint"]
local_df = pd.DataFrame(local_rows, columns=column_names_local)
local_df
# Out:
#                                             Title               Author  Year  \
# 0     10 minutes 38 seconds in this strange world          Elif Shafak  2019
# 1            2034 : a novel of the next world war      Elliot Ackerman  2021
# 2                            28 summers : a novel     Elin Hilderbrand  2020
# 3                                      29 seconds            T M Logan  2019
# 4                                        48 hours  William R Forstchen  2019
# ...                                           ...                  ...   ...
# 2715                Your house will pay : a novel            Steph Cha  2019
# 2716                   Yours cheerfully : a novel           A J Pearce  2021
# 2717                                Zed : a novel       Joanna Kavenna  2020
# 2718                                Zero sum game            S L Huang  2018
# 2719                             Zorrie : a novel           Laird Hunt  2021
#
#      Location                                         MatchPoint
# 0        lina  Elif Shafak 10 minutes 38 seconds in this stra...
# 1        lina  Elliot Ackerman 2034 : a novel of the next wor...
# 2        lina              Elin Hilderbrand 28 summers : a novel
# 3        lina                               T M Logan 29 seconds
# 4        lina                       William R Forstchen 48 hours
# ...       ...                                                ...
# 2715     lina            Steph Cha Your house will pay : a novel
# 2716    linan              A J Pearce Yours cheerfully : a novel
# 2717     lina                       Joanna Kavenna Zed : a novel
# 2718     lina                            S L Huang Zero sum game
# 2719    linan                        Laird Hunt Zorrie : a novel
#
# [2720 rows x 5 columns]

# %%
local_df[local_df['MatchPoint'].str.match('Daniel José')]
# Out:
#                         Title             Author  Year Location  \
# 1678  The book of lost saints  Daniel José Older  2019     lina
#
#                                      MatchPoint
# 1678  Daniel José Older The book of lost saints

# %%
def ngrams(string, n=3):
    """Takes an input string, cleans it and converts to ngrams. 
    This script is focussed on cleaning UK company names but can be made generic by removing lines below"""
    string = str(string)
    string = string.lower() # lower case
    #string = fix_text(string) # fix text
    string = string.encode("ascii", errors="ignore").decode() #remove non ascii chars
    chars_to_remove = [")","(",".","|","[","]","{","}","'","-"]
    rx = '[' + re.escape(''.join(chars_to_remove)) + ']' #remove punc, brackets etc...
    string = re.sub(rx, '', string)
    string = re.sub(' +',' ',string).strip() # get rid of multiple spaces and replace with a single
    string = ' '+ string +' ' # pad names for ngrams...
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]


###FIRST TIME RUN - takes about 5 minutes... used to build the matching table

##### Create a list of items to match here:
comp_match = list(comp_df["MatchPoint"].unique()) #unique org names from company watch file
#Building the TFIDF off the clean dataset - takes about 5 min
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(comp_match)

##### Create a list of messy items to match here:
local_match = list(local_df["MatchPoint"].unique()) #unique list of names


messy_tf_idf_matrix = vectorizer.transform(local_match)

# %%
# create a random matrix to index
data_matrix = tf_idf_matrix#[0:1000000]

# Set index parameters
# These are the most important ones
M = 80
efC = 1000

num_threads = 4 # adjust for the number of threads
# Intitialize the library, specify the space, the type of the vector and add data points 
index = nmslib.init(method='simple_invindx', space='negdotprod_sparse_fast', data_type=nmslib.DataType.SPARSE_VECTOR) 

index.addDataPointBatch(data_matrix)
# Create an index
index.createIndex()

# %%
# Number of neighbors 
num_threads = 4
K=1
query_matrix = messy_tf_idf_matrix

query_qty = query_matrix.shape[0]
nbrs = index.knnQueryBatch(query_matrix, k = K, num_threads = num_threads)

# %%
mts =[]
for i in range(len(nbrs)):
  original_nm = local_match[i]
  try:
    matched_nm   = comp_match[nbrs[i][0][0]]
    conf         = nbrs[i][1][0] * -1
  except:
    matched_nm   = "no match found"
    conf         = None
  mts.append([original_nm,matched_nm,conf])

mts = pd.DataFrame(mts,columns=['comp_match','local_match','conf'])

# %%
mts = mts.sort_values(by=['conf'])
mts
# Out:
#                                              comp_match  \
# 2527             1972- author Lilja Sigurðardóttir Trap
# 1233                       Alastair Reynolds Permafrost
# 1190                           María Gainza Optic nerve
# 2388           Seth Dickinson The tyrant Baru Cormorant
# 660                           Owen Laukkanen Gale force
# ...                                                 ...
# 2009          Chanel Cleeton The last train to Key West
# 0     Elif Shafak 10 minutes 38 seconds in this stra...
# 2628            Sigrid Nunez What are you going through
# 465                      James McBride Deacon King Kong
# 2102     Chanel Cleeton The most beautiful girl in Cuba
#
#                                             local_match      conf
# 2527                          Julie Tieu The Donut Trap  0.138503
# 1233                        A.C. Arthur The Last Affair  0.146572
# 1190                       Sarah Gailey Taste of Marrow  0.147769
# 2388                             Ruth Dickey Mud Blooms  0.148670
# 660   Ed Morales Latinx: The New Force in American P...  0.152833
# ...                                                 ...       ...
# 2009          Chanel Cleeton The Last Train to Key West  1.000000
# 0     Elif Shafak 10 Minutes 38 Seconds in This Stra...  1.000000
# 2628            Sigrid Nunez What Are You Going Through  1.000000
# 465                      James McBride Deacon King Kong  1.000000
# 2102     Chanel Cleeton The Most Beautiful Girl in Cuba  1.000000
#
# [2717 rows x 3 columns]

# %%
mts[mts['local_match'].str.match('Daniel José')]
# Out:
#                                            comp_match  \
# 1674  Lisa Wingate The book of lost friends : a novel
# 1675  Kristin Harmel The book of lost names : a novel
# 1676        Daniel José Older The book of lost saints
#
#                                     local_match      conf
# 1674  Daniel José Older The Book of Lost Saints  0.325401
# 1675  Daniel José Older The Book of Lost Saints  0.335621
# 1676  Daniel José Older The Book of Lost Saints  1.000000

# %%
mts[mts['conf']<= .66]
# Out:
#                                               comp_match  \
# 22351                   B Akunin Ubitʹ zmeenysha : pʹesa
# 9534   Alekseĭ Zhivoĭ Legion : Pryzhok lʹva ; Ispansk...
# 2115     Zaynab ʻAfīfī Aḥlum wa-anā bi-jiwārak : riwāyah
# 13706  V V Erofeev Roz︠h︡eva Mysha : Nevelykyĭ mahich...
# 22354                               N Zhivotov Ubiĭt︠s︡a
# ...                                                  ...
# 13464                Rebecca Roanhorse Resistance reborn
# 687                          M J Tjia A necessary murder
# 4391                  Pola Oloixarac Dark constellations
# 16278                Emma Donoghue The Lotterys plus one
# 13365  Christian Staebler Redbone : the true story of...
#
#                                              local_match      conf
# 22351                                Victoria Chang Obit  0.093450
# 9534          Nikki Giovanni Make Me Rain: Poems & Prose  0.095440
# 2115   Zakiyyah Iman Jackson Becoming Human: Matter a...  0.098011
# 13706  Ruha Benjamin Race After Technology: Abolition...  0.098256
# 22354  Lun Zhang Adrien Gombeaud, and Améziane, Tiana...  0.098477
# ...                                                  ...       ...
# 13464                        Rebecca Roanhorse Black Sun  0.652681
# 687                         M.J. Tija A Necessary Murder  0.654089
# 4391                                 Pola Oloixarac Mona  0.654350
# 16278                                 Emma Donoghue Akin  0.656727
# 13365  Christian Stabler Sonia Paoloni, Thibault Bala...  0.657117
#
# [22922 rows x 3 columns]

# %%
mts.to_excel("matched_output.xlsx")

# %%
print('estimated percentage of titles in collection '+ str(round((len(mts.loc[mts['conf'] > .66]) / len(comp_df))*100,2)) +'%')
# Out:
# estimated percentage of titles in collection 8.17%

# %%
fiction_df = comp_df[comp_df['Genre']=='Fiction']

# %%
fiction_df
# Out:
#          Genre          Author  \
# 0      Fiction  Charlie Adhara
# 1      Fiction  Charlie Adhara
# 2      Fiction  Charlie Adhara
# 3      Fiction  Charlie Adhara
# 4      Fiction     Brea Alepoú
# ...        ...             ...
# 4012   Fiction
# 4013   Fiction
# 4014   Fiction
# 4015   Fiction
# Genre  Fiction         Fiction
#
#                                                    Title     Year  \
# 0                                   The Wolf at the Door   2018.0
# 1                                        The Wolf at Bay   2018.0
# 2                                   Thrown to the Wolves   2019.0
# 3                               Wolf in Sheep’s Clothing   2020.0
# 4                                    His Bewildered Mate   2019.0
# ...                                                  ...      ...
# 4012                  Slay: Stories of the Vampire Noire   2020.0
# 4013   Transcendent 3: The Year’s Best Transgender Sp...   2018.0
# 4014                                      Transcendent 4   2019.0
# 4015   Walking the Clouds: An Anthology of Indigenous...   2012.0
# Genre                                            Fiction  Fiction
#
#                                               MatchPoint
# 0                    Charlie Adhara The Wolf at the Door
# 1                         Charlie Adhara The Wolf at Bay
# 2                    Charlie Adhara Thrown to the Wolves
# 3                Charlie Adhara Wolf in Sheep’s Clothing
# 4                        Brea Alepoú His Bewildered Mate
# ...                                                  ...
# 4012                  Slay: Stories of the Vampire Noire
# 4013    Transcendent 3: The Year’s Best Transgender S...
# 4014                                      Transcendent 4
# 4015    Walking the Clouds: An Anthology of Indigenou...
# Genre                                            Fiction
#
# [4017 rows x 5 columns]

# %%
print('estimated percentage of titles in fiction collection '+ str(round((len(mts.loc[mts['conf'] > .66]) / len(fiction_df))*100,2)) +'%')
# Out:
# estimated percentage of titles in fiction collection 8.17%

# %%
fiction_result = pd.merge(fiction_df,mts[mts['conf']> .66], left_on='MatchPoint',right_on='comp_match', how='left')

# %%
fiction_result
# Out:
#         Genre          Author  \
# 0     Fiction  Charlie Adhara
# 1     Fiction  Charlie Adhara
# 2     Fiction  Charlie Adhara
# 3     Fiction  Charlie Adhara
# 4     Fiction     Brea Alepoú
# ...       ...             ...
# 4012  Fiction
# 4013  Fiction
# 4014  Fiction
# 4015  Fiction
# 4016  Fiction         Fiction
#
#                                                   Title     Year  \
# 0                                  The Wolf at the Door   2018.0
# 1                                       The Wolf at Bay   2018.0
# 2                                  Thrown to the Wolves   2019.0
# 3                              Wolf in Sheep’s Clothing   2020.0
# 4                                   His Bewildered Mate   2019.0
# ...                                                 ...      ...
# 4012                 Slay: Stories of the Vampire Noire   2020.0
# 4013  Transcendent 3: The Year’s Best Transgender Sp...   2018.0
# 4014                                     Transcendent 4   2019.0
# 4015  Walking the Clouds: An Anthology of Indigenous...   2012.0
# 4016                                            Fiction  Fiction
#
#                                              MatchPoint comp_match  \
# 0                   Charlie Adhara The Wolf at the Door        NaN
# 1                        Charlie Adhara The Wolf at Bay        NaN
# 2                   Charlie Adhara Thrown to the Wolves        NaN
# 3               Charlie Adhara Wolf in Sheep’s Clothing        NaN
# 4                       Brea Alepoú His Bewildered Mate        NaN
# ...                                                 ...        ...
# 4012                 Slay: Stories of the Vampire Noire        NaN
# 4013   Transcendent 3: The Year’s Best Transgender S...        NaN
# 4014                                     Transcendent 4        NaN
# 4015   Walking the Clouds: An Anthology of Indigenou...        NaN
# 4016                                            Fiction        NaN
#
#      local_match  conf
# 0            NaN   NaN
# 1            NaN   NaN
# 2            NaN   NaN
# 3            NaN   NaN
# 4            NaN   NaN
# ...          ...   ...
# 4012         NaN   NaN
# 4013         NaN   NaN
# 4014         NaN   NaN
# 4015         NaN   NaN
# 4016         NaN   NaN
#
# [4017 rows x 8 columns]

# %%
fiction_result.to_excel("fiction_matched_output.xlsx")

# %%
mts[mts["comp_match"].str.match('Rebecca Roanhorse')]
# Out:
#                                  comp_match  \
# 13464   Rebecca Roanhorse Resistance reborn
# 13170     Rebecca Roanhorse Race to the sun
# 15218    Rebecca Roanhorse Storm of locusts
# 22080  Rebecca Roanhorse Trail of lightning
# 2752            Rebecca Roanhorse Black sun
#
#                                 local_match      conf
# 13464           Rebecca Roanhorse Black Sun  0.652681
# 13170           Rebecca Roanhorse Black Sun  0.815647
# 15218    Rebecca Roanhorse Storm of Locusts  1.000000
# 22080  Rebecca Roanhorse Trail of Lightning  1.000000
# 2752            Rebecca Roanhorse Black Sun  1.000000
