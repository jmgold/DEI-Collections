# %%
import sqlite3
import pandas as pd
import psycopg2
import configparser

# %%
try:
    sqliteConnection = sqlite3.connect('DEI Database.db')
    cursor = sqliteConnection.cursor()
    print("Connected to SQLite")
    
    sql_query = """SELECT *
                FROM title_list
                """
    cursor.execute(sql_query)
    sqliteConnection.commit()
    dei_rows = cursor.fetchall()
    cursor.close()
except sqlite3.Error as error:
    print("Failed to run query", error)
# Out:
# Connected to SQLite

# %%
column_names = ["Genre","Author","Title","Year"]
dei_df = pd.DataFrame(dei_rows, columns=column_names)

# %%
dei_df
# Out:
#                      Genre            Author  \
# 0   Romance/Erotic Romance    Charlie Adhara
# 1   Romance/Erotic Romance    Charlie Adhara
# 2   Romance/Erotic Romance    Charlie Adhara
# 3   Romance/Erotic Romance    Charlie Adhara
# 4   Romance/Erotic Romance       Brea Alepoú
# 5   Romance/Erotic Romance       Brea Alepoú
# 6   Romance/Erotic Romance       Brea Alepoú
# 7   Romance/Erotic Romance       Brea Alepoú
# 8   Romance/Erotic Romance       Brea Alepoú
# 9   Romance/Erotic Romance       Brea Alepoú
# 10  Romance/Erotic Romance       Brea Alepoú
# 11  Romance/Erotic Romance       Brea Alepoú
# 12  Romance/Erotic Romance       Brea Alepoú
# 13  Romance/Erotic Romance  Kianna Alexander
# 14  Romance/Erotic Romance  Kianna Alexander
# 15  Romance/Erotic Romance  Kianna Alexander
# 16  Romance/Erotic Romance  Kianna Alexander
# 17  Romance/Erotic Romance  Kianna Alexander
# 18  Romance/Erotic Romance  Kianna Alexander
# 19  Romance/Erotic Romance  Kianna Alexander
# 20  Romance/Erotic Romance  Kianna Alexander
# 21  Romance/Erotic Romance    Rochelle Alers
# 22  Romance/Erotic Romance    Rochelle Alers
# 23  Romance/Erotic Romance    Rochelle Alers
# 24  Romance/Erotic Romance    Rochelle Alers
# 25  Romance/Erotic Romance    Rochelle Alers
# 26  Romance/Erotic Romance    Rochelle Alers
# 27  Romance/Erotic Romance    Rochelle Alers
# 28  Romance/Erotic Romance    Danielle Allen
# 29  Romance/Erotic Romance    Danielle Allen
# 30  Romance/Erotic Romance    Danielle Allen
# 31  Romance/Erotic Romance    Danielle Allen
# 32  Romance/Erotic Romance    Danielle Allen
# 33  Romance/Erotic Romance    Danielle Allen
# 34  Romance/Erotic Romance    Danielle Allen
# 35  Romance/Erotic Romance       Dylan Allen
# 36  Romance/Erotic Romance       Dylan Allen
# 37  Romance/Erotic Romance       Dylan Allen
# 38  Romance/Erotic Romance       Dylan Allen
# 39  Romance/Erotic Romance       Dylan Allen
# 40  Romance/Erotic Romance    Michelle Arris
# 41  Romance/Erotic Romance       A.C. Arthur
# 42  Romance/Erotic Romance       A.C. Arthur
# 43  Romance/Erotic Romance       A.C. Arthur
# 44  Romance/Erotic Romance       A.C. Arthur
# 45  Romance/Erotic Romance       A.C. Arthur
# 46  Romance/Erotic Romance       A.C. Arthur
# 47  Romance/Erotic Romance       A.C. Arthur
# 48  Romance/Erotic Romance       A.C. Arthur
# 49  Romance/Erotic Romance       A.C. Arthur
#
#                                                 Title  Year
# 0                                The Wolf at the Door  2018
# 1                                     The Wolf at Bay  2018
# 2                                Thrown to the Wolves  2019
# 3                            Wolf in Sheep’s Clothing  2020
# 4                                 His Bewildered Mate  2019
# 5                             Never Trust a Porn Star  2019
# 6                                   Finding Mr. Claus  2019
# 7                   A King to Be Protected: Gay Harem  2019
# 8          Their Blood: MMMMM Dark Paranormal Romance  2020
# 9                                      His Royal Mate  2020
# 10                              His Apprehensive Mate  2020
# 11  Inconvenient Attachments: Dark MMM Paranormal ...  2020
# 12                                   His Runaway Mate  2020
# 13                                  Love For All Time  2018
# 14                              Couldn’t Ask for More  2018
# 15    Forever with You & The Sweet Taste of Seduction  2019
# 16                  Then Came You & Written With Love  2019
# 17                                    Never Let Me Go  2020
# 18                                 The Wedding Secret  2020
# 19                             After Hours Redemption  2020
# 20                             After Hours Attraction  2021
# 21                                The Long Hot Summer  2019
# 22                                       The Only Man  2019
# 23                                   The Bridal Suite  2019
# 24                           Second-Chance Sweet Shop  2019
# 25                     Starting Over in Wickham Falls  2020
# 26                                   The Seaside Cafe  2020
# 27                                    The Beach House  2021
# 28                                          Tell-Tale  2019
# 29                                V is for Villainous  2019
# 30                                  V is for Vengeful  2019
# 31                                  Annabelle and Lee  2020
# 32  Slow News Day: A Groundhog Day Hot Holiday Hookup  2020
# 33  Fool in Love: An April Fool’s Day Hot Holiday ...  2020
# 34                           Trouble’s What You’re In  2020
# 35                                         The Legacy  2018
# 36                               The Sun and Her Star  2018
# 37                                         The Legend  2019
# 38                            Between Now and Forever  2019
# 39                                        The Jezebel  2020
# 40                                             See Me  2019
# 41                                        Lover’s Bid  2019
# 42                                    A Cougar’s Kiss  2019
# 43                                  Awaken the Dragon  2019
# 44                                      Office Policy  2019
# 45                                Corporate Seduction  2019
# 46                                 Laws of Attraction  2019
# 47                                   A Private Affair  2020
# 48                                              Roark  2020
# 49                                   Claim the Dragon  2020

# %%
config = configparser.ConfigParser()
config.read('Y:\\SQL Reports\\creds\\app_SIC.ini')

try:
    query = """SELECT
b.best_title AS title,
REPLACE(SPLIT_PART(SPLIT_PART(b.best_author,' (',1),', ',2),'.','')||' '||SPLIT_PART(b.best_author,', ',1) AS author,
SUBSTRING(i.location_code FROM 1 FOR 3) AS location,
CASE
WHEN COUNT(i.id) != 0 THEN TRUE
ELSE FALSE
END AS owns
FROM
sierra_view.bib_record_property b
JOIN
sierra_view.bib_record_item_record_link l
ON
b.bib_record_id = l.bib_record_id
JOIN
sierra_view.item_record i
ON
l.item_record_id = i.id
WHERE
b.material_code = 'a'
AND b.publish_year >= 2018

GROUP BY 1,2,3
ORDER BY 1,2,3
    """
    #variable connection string should be defined in the imported config file
    conn = psycopg2.connect( config['db']['connection_string'] )
except:
    print("unable to connect to the database")
    clear_connection()
cursor = conn.cursor()
cursor.execute(query)
#For now, just storing the data in a variable. We'll use it later.
sierra_rows = cursor.fetchall()
conn.close()
    
column_names_sierra = ["Title", "Author", "Location", "Owns"]
sierra_df = pd.DataFrame(sierra_rows, columns=column_names_sierra)

# %%
sierra_df
# Out:
#                                                     Title  \
# 0         Amanda's Dream (English Hebrew Bilingual Book)
# 1         El Nuevo Bebé (the New Baby) (Ana & Andrew S...
# 2         El Nuevo Bebé (the New Baby) (Ana & Andrew S...
# 3                  After High School: A Guide To Help You
# 4                    Arsène Lupin Versus Herlock Sholmes
# ...                                                   ...
# 743589                           Ṭayf al-Ḥallāj : riwāyah
# 743590                                         Ṭopī Śuklā
# 743591                         Ẓilāl al-ākharīn : riwāyah
# 743592                                                偷溜蛋
# 743593                      鷹與烏鴉 = The hawk and the crow.
#
#                             Author Location  Owns
# 0                   Shelley Admont      fp2  True
# 1                  Christine Platt      fp2  True
# 2                  Christine Platt      fpl  True
# 3                     Brian Harris      ntn  True
# 4                  Maurice Leblanc      ntn  True
# ...                            ...      ...   ...
# 743589          Maqbūl Mūsá ʻAlawī      ntn  True
# 743590  1927-1992 Rāhī Māsūma Razā      act  True
# 743591                Manāf Zaytūn      ntn  True
# 743592                    約翰 (John      wlm  True
# 743593                      Aesop.      frk  True
#
# [743594 rows x 4 columns]

# %%
sierra_limited = sierra_df[sierra_df["Owns"] == True]

# %%
sierra_limited
# Out:
#                                                     Title  \
# 0         Amanda's Dream (English Hebrew Bilingual Book)
# 1         El Nuevo Bebé (the New Baby) (Ana & Andrew S...
# 2         El Nuevo Bebé (the New Baby) (Ana & Andrew S...
# 3                  After High School: A Guide To Help You
# 4                    Arsène Lupin Versus Herlock Sholmes
# ...                                                   ...
# 743589                           Ṭayf al-Ḥallāj : riwāyah
# 743590                                         Ṭopī Śuklā
# 743591                         Ẓilāl al-ākharīn : riwāyah
# 743592                                                偷溜蛋
# 743593                      鷹與烏鴉 = The hawk and the crow.
#
#                             Author Location  Owns
# 0                   Shelley Admont      fp2  True
# 1                  Christine Platt      fp2  True
# 2                  Christine Platt      fpl  True
# 3                     Brian Harris      ntn  True
# 4                  Maurice Leblanc      ntn  True
# ...                            ...      ...   ...
# 743589          Maqbūl Mūsá ʻAlawī      ntn  True
# 743590  1927-1992 Rāhī Māsūma Razā      act  True
# 743591                Manāf Zaytūn      ntn  True
# 743592                    約翰 (John      wlm  True
# 743593                      Aesop.      frk  True
#
# [743594 rows x 4 columns]

# %%
try:
    sqliteConnection = sqlite3.connect('DEI Database.db')
    cursor = sqliteConnection.cursor()
    print("Connected to SQLite")
    
    sql_query = """SELECT LOWER(REPLACE(Title,'''',''))||LOWER(REPLACE(Author,'''','')) 
                FROM title_list
                """
    cursor.execute(sql_query)
    sqliteConnection.commit()
    title_match = cursor.fetchall()
    title_string = [t[0] for t in title_match]
    cursor.close()
except sqlite3.Error as error:
    print("Failed to run query", error)
# Out:
# Connected to SQLite

# %%
title_string
# Out:
# ['the wolf at the doorcharlie adhara',
#  'the wolf at baycharlie adhara',
#  'thrown to the wolvescharlie adhara',
#  'wolf in sheep’s clothingcharlie adhara',
#  'his bewildered matebrea alepoú',
#  'never trust a porn starbrea alepoú',
#  'finding mr. clausbrea alepoú',
#  'a king to be protected: gay harembrea alepoú',
#  'their blood: mmmmm dark paranormal romancebrea alepoú',
#  'his royal matebrea alepoú',
#  'his apprehensive matebrea alepoú',
#  'inconvenient attachments: dark mmm paranormal romancebrea alepoú',
#  'his runaway matebrea alepoú',
#  'love for all timekianna alexander',
#  'couldn’t ask for morekianna alexander',
#  'forever with you & the sweet taste of seductionkianna alexander',
#  'then came you & written with lovekianna alexander',
#  'never let me gokianna alexander',
#  'the wedding secretkianna alexander',
#  'after hours redemptionkianna alexander',
#  'after hours attractionkianna alexander',
#  'the long hot summerrochelle alers',
#  'the only manrochelle alers',
#  'the bridal suiterochelle alers',
#  'second-chance sweet shoprochelle alers',
#  'starting over in wickham fallsrochelle alers',
#  'the seaside caferochelle alers',
#  'the beach houserochelle alers',
#  'tell-taledanielle allen',
#  'v is for villainousdanielle allen',
#  'v is for vengefuldanielle allen',
#  'annabelle and leedanielle allen',
#  'slow news day: a groundhog day hot holiday hookupdanielle allen',
#  'fool in love: an april fool’s day hot holiday hookupdanielle allen',
#  'trouble’s what you’re indanielle allen',
#  'the legacydylan allen',
#  'the sun and her stardylan allen',
#  'the legenddylan allen',
#  'between now and foreverdylan allen',
#  'the jezebeldylan allen',
#  'see memichelle arris',
#  'lover’s bida.c. arthur',
#  'a cougar’s kissa.c. arthur',
#  'awaken the dragona.c. arthur',
#  'office policya.c. arthur',
#  'corporate seductiona.c. arthur',
#  'laws of attractiona.c. arthur',
#  'a private affaira.c. arthur',
#  'roarka.c. arthur',
#  'claim the dragona.c. arthur',
#  'at your servicea.c. arthur',
#  'the last affaira.c. arthur',
#  'call the coroneravril ashton',
#  'kiss your scarsavril ashton',
#  'dig your graveavril ashton',
#  'remember meavril ashton',
#  'make me stayamarie avant',
#  'the weddingamarie avant',
#  'neverjoy avery',
#  'maybejoy avery',
#  'alwaysjoy avery',
#  'a bid on foreverjoy avery',
#  'forever with you & the sweet taste of seductionjoy avery',
#  'then came you & written with lovejoy avery',
#  '14 days & other storiesola awonubi',
#  'when frankie meets johnnyxio axelrod',
#  'honey & spicebolu babalola',
#  'christmas in evergreen: bells are ringinglacey baker',
#  'grey dawn: a tale of abolition and unionnyri bakkalian',
#  'rescue mecheryl barton',
#  'true lies or true lovecheryl barton',
#  'she said nocheryl barton',
#  'swagger and baggagecheryl barton',
#  'release mecheryl barton',
#  'dashing through the snowcheryl barton',
#  'claiming his childcheryl barton',
#  'always bet on blackcheryl barton',
#  'destination weddingdiksha basu',
#  'second chance with her billionairetherese beharrie',
#  'from heiress to momtherese beharrie',
#  'island fling with the tycoontherese beharrie',
#  'her twin baby secrettherese beharrie',
#  'one last chancetherese beharrie',
#  'marrying his runaway heiresstherese beharrie',
#  'his princess by christmastherese beharrie',
#  'when worlds collidemillie belizaire',
#  'when hearts collidemillie belizaire',
#  'when souls collidemillie belizaire',
#  'holiday surprisemillie belizaire',
#  'the garden of edenmillie belizaire',
#  'written in the starsalexandria bellefleur',
#  'hang the moonalexandria bellefleur',
#  'count your lucky starsalexandria bellefleur',
#  'he who is a friendlove belvin',
#  'he who is a loverlove belvin',
#  'he who is a protectorlove belvin',
#  'the rules of arrangementanisha bhatia',
#  'blessedmaggie blackbird',
#  'redeemedmaggie blackbird',
#  'sanctifiedmaggie blackbird',
#  'tied up with a bowmaggie blackbird',
#  'thanks to youmaggie blackbird',
#  'renewedmaggie blackbird',
#  'dressed for successmaggie blackbird',
#  'after the snow meltsmaggie blackbird',
#  'the greek’s hidden vowsmaya blake',
#  'gridiron bad boymelissa blue',
#  'gridiron heartbreakermelissa blue',
#  'dirty sexy scotmelissa blue',
#  'grumpy jakemelissa blue',
#  'crazy in lovecrystal b. bright',
#  'love like crazycrystal b. bright',
#  'crazy on youcrystal b. bright',
#  'redesigning happinessnita brooks',
#  'the essence of perfectionnita brooks',
#  'nice guys don’t finish lastchavez l. brown',
#  'a perfect mistakelaura brown',
#  'madam, may iniobia bryant',
#  'strong lovingniobia bryant',
#  'christmas with the billionaire/a tiara for christmasniobia bryant',
#  'wild women and the bluesdenny bryce',
#  'faux ho honathan burgoine',
#  'spindriftanna burke',
#  'night tideanna burke',
#  'no love for the wickedjessica cage',
#  'an acquired tastekelly cain',
#  'the heart of thingsj.l. campbell',
#  'forever minej.l. campbell',
#  'the blind shotj.l. campbell',
#  'kings of the castlej.l. campbell',
#  'the pain of thingsj.l. campbell',
#  'dnaj.l. campbell',
#  'knight of paradise islandj.l. campbell',
#  'the cost of hopeg.s. carr',
#  'the cost of atonementg.s. carr',
#  'the cost of rebelliong.s. carr',
#  'lady of secretsg.s. carr',
#  'deena’s deceptiong.s. carr',
#  'lady of disguiseg.s. carr',
#  'heart and handrebel carter',
#  'natasharebel carter',
#  'new girl in townrebel carter',
#  'ashleyrebel carter',
#  'love and gravityrebel carter',
#  'hearth and homerebel carter',
#  'honor and desirerebel carter',
#  'three to loverebel carter',
#  'leather and lacerebel carter',
#  'new girl in the cityrebel carter',
#  'enemies to lovers v. 1rebel carter',
#  'pride and passionrebel carter',
#  'strippedzoey castile',
#  'hiredzoey castile',
#  'flashedzoey castile',
#  'homecomingceleste castro',
#  'prize moneyceleste castro',
#  'caroline’s heartaustin chant',
#  'christmas at the palacejeevani charika',
#  'this stolen lifejeevani charika',
#  'a convenient marriagejeevani charika',
#  'not the girl you marryandie j. christopher',
#  'not that kind of guyandie j. christopher',
#  'hot under his collarandie j. christopher',
#  'everything i needann christopher',
#  'everything i hoped forann christopher',
#  'all of meann christopher',
#  'somebody to loveann christopher',
#  'the view was exhaustingmikaella clements and onjuli datta',
#  'a princess in theoryalyssa cole',
#  'a duke by defaultalyssa cole',
#  'once ghosted, twice shyalyssa cole',
#  'an unconditional freedomalyssa cole',
#  'can’t escape lovealyssa cole',
#  'a prince on paperalyssa cole',
#  'the a.i. who loved mealyssa cole',
#  'how to catch a queenalyssa cole',
#  'how to find a princessalyssa cole',
#  'worth it allclaudia connor',
#  'accusedsharon c. cooper',
#  'soul’s desiresharon c. cooper',
#  'betrayedsharon c. cooper',
#  'more than lovesharon c. cooper',
#  'show mesharon c. cooper',
#  'huntedsharon c. cooper',
#  'his to protectsharon c. cooper',
#  'life on the levelzoraida córdova',
#  'finding giorgiojoe cosentino',
#  'finding armandojoe cosentino',
#  'seducing his secret wiferobin covington',
#  'insiderrebecca crowley',
#  'undercoverrebecca crowley',
#  'off the recordrebecca crowley',
#  'brooklyn summermaggie cummings',
#  'take the leadalexis daria',
#  'dance with mealexis daria',
#  'dance all nightalexis daria',
#  'you had me at holaalexis daria',
#  'a lot like adiósalexis daria',
#  'in helen’s handsnanisi barrett darnuk',
#  'the followeliza david',
#  'the follow 2: blockedeliza david',
#  'the lamar st. jon experienceeliza david',
#  'hard harte. davies',
#  'changed harte. davies',
#  'redemptione. davies',
#  'wild harte. davies',
#  'edge of nowherefelicia davin',
#  'thornfruitfelicia davin',
#  'nightvinefelicia davin',
#  'shadebloomfelicia davin',
#  'out of nowherefelicia davin',
#  'stay a little longershay davis',
#  'stay forevershay davis',
#  'just wanna be lovedshay davis',
#  'a dash of christmas magicshay davis',
#  'the marriage contractshay davis',
#  'just wanna be loved tooshay davis',
#  'love aftershay davis',
#  'sin city vowszuri day',
#  'sweet heatzuri day',
#  'ready for the rancherzuri day',
#  'sin city seductionzuri day',
#  'to love a scandalous dukeliana de la rosa',
#  'to resist a scandalous rogueliana de la rosa',
#  'to tame a scandalous ladyliana de la rosa',
#  'mistletoe in texaskari lynn dell',
#  'last chance rodeokari lynn dell',
#  'relentless in texaskari lynn dell',
#  'temptationchiquita dennie',
#  'i deserve his lovechiquita dennie',
#  'the marriage gamesara desai',
#  'the dating plansara desai',
#  'the singles tablesara desai',
#  'pride, prejudice, and other flavorssonali dev',
#  'a recipe for persuasionsonali dev',
#  'incense and sensibilitysonali dev',
#  'princess of zamibiadelaney diamond',
#  'heart’s desiredelaney diamond',
#  'two nights in parisdelaney diamond',
#  'deeper than lovedelaney diamond',
#  'without youdelaney diamond',
#  'princess of estoriadelaney diamond',
#  'never againdelaney diamond',
#  'queen of barrakeschdelaney diamond',
#  'conspiracyde’nesha diamond',
#  'collusionde’nesha diamond',
#  'collateralde’nesha diamond',
#  'revolutionary heartspema donyo',
#  'fierce justicepiper j. drake',
#  'keeping cadencepiper j. drake',
#  'forever strongpiper j. drake',
#  'gaming gracepiper j. drake',
#  'everything’s better with youlucy eden',
#  'cherishing the goddesslucy eden',
#  'an angel for daddylucy eden',
#  'everything’s better with kimberlylucy eden',
#  'afternoon delightlucy eden',
#  'everything’s better with lisalucy eden',
#  'bear with melucy eden',
#  'resolutionslucy eden',
#  'upsy daisychelsie edwards',
#  'the other side of forestlands lakecarolyn elizabeth',
#  'the carpenter’s princejayce ellis',
#  'jeremiahjayce ellis',
#  'andréjayce ellis',
#  'on pointeshelly ellis',
#  'her new grooveshelly ellis',
#  'love grindshelly ellis',
#  'whippederos',
#  'what kind of daymina v. esguerra',
#  'kiss and crymina v. esguerra',
#  'switched at bidnicole falls',
#  'a natural transitionnicole falls',
#  'shots not takennicole falls',
#  'someone seeking someone elsenicole falls',
#  'the changeupnicole falls',
#  'a merry little filthmasnicole falls',
#  'the restartnicole falls',
#  'a dirty valentinenicole falls',
#  'a good luck f*cknicole falls',
#  'love under quarantinenicole falls',
#  'release some tensionnicole falls',
#  'like breathingtia fielding',
#  'tentia fielding',
#  'fourtia fielding',
#  'silent nightsnia forrester',
#  'not that kind of girlnia forrester',
#  'bound tosionna fox',
#  'tied upsionna fox',
#  'heart and seouljen frederick',
#  'four letter wordava freeman',
#  'fire we makeava freeman',
#  'belong to youava freeman',
#  'friends & loversava freeman',
#  'four letter word 2ava freeman',
#  'a taste of remyava freeman',
#  'friends & lovers 2ava freeman',
#  'friends & lovers 3ava freeman',
#  'be minesavannah frierson',
#  'grounded for christmassavannah frierson',
#  'tony and leandra: complete seriesjimi gaillard-jefferson',
#  'friends to lovers: complete cassidy and cahir seriesjimi gaillard-jefferson',
#  'hopeless romanticfrancis gideon',
#  'charming like a wolftina glasneck',
#  'the love conseressia glass',
#  'knit one, girl twoshira glassman',
#  'gifts of springshira glassman',
#  'exclusively yoursnadine gonzalez',
#  'unconditionally minenadine gonzalez',
#  'scandal in the vip suitenadine gonzalez',
#  'what happens in miami…nadine gonzalez',
#  'fate’s matchelysabeth grace',
#  'your heart onlyelysabeth grace',
#  'fate’s kisselysabeth grace',
#  'along for the ridemimi grace',
#  'make a scenemimi grace',
#  'the contingency bidsherelle green',
#  'her christmas wish/designed by lovesherelle green',
#  'black friday: high life short storysherelle green',
#  'her undeniable attractionsherelle green',
#  'caden’s situationshipsherelle green',
#  'summer kisses: carnivale chroniclessherelle green',
#  'carter’s undoingsherelle green',
#  'yours ever aftersherelle green',
#  'a return to armssheree l. greer',
#  'fire and obsidianandrew grey',
#  'on shaky groundandrew grey',
#  'survive and conquerandrew grey',
#  'heartwardandrew grey',
#  'pulling stringsandrew grey',
#  'fire and onyxandrew grey',
#  'above and beyondandrew grey',
#  'catch of a lifetimeandrew grey',
#  'hard road backandrew grey',
#  'fire and diamondandrew grey',
#  'paint by numberandrew grey',
#  'bad to be goodandrew grey',
#  'half a cowboyandrew grey',
#  'bad to be worthyandrew grey',
#  'the game warden’s matea.m. griffin',
#  'hunted by the alien princea.m. griffin',
#  'the alien king’s desirea.m. griffin',
#  'appetites & vicesfelicia grossman',
#  'dalliances & devotionfelicia grossman',
#  'the wedding datejasmine guillory',
#  'the proposaljasmine guillory',
#  'the wedding partyjasmine guillory',
#  'royal holidayjasmine guillory',
#  'party of twojasmine guillory',
#  'while we were datingjasmine guillory',
#  'can’t help falling in loveprachi gupta',
#  'not my type of strangerprachi gupta',
#  'chasing mindycarla de guzman',
#  'how she likes itcarla de guzman',
#  'how to blow it with a billionairealexis hall',
#  'how to belong with a billionairealexis hall',
#  'boyfriend materialalexis hall',
#  'rosaline palmer takes the cakealexis hall',
#  'the duke who loved mealexis hall',
#  'unwrap mejack harbon',
#  'the babysitterjack harbon',
#  'kittenjack harbon',
#  'daddyjack harbon',
#  'the truth of thingstasha l. harrison',
#  'a taste of her own medicinetasha l. harrison',
#  'the bad in each othertasha l. harrison',
#  'her seductive darelena hart',
#  'hexhunterjordan l. hawk',
#  'stalker of shadowsjordan l. hawk',
#  'deosiljordan l. hawk',
#  'the chai factorfarah heron',
#  'accidentally engagedfarah heron',
#  'american dreameradriana herrera',
#  'american fairytaleadriana herrera',
#  'american love storyadriana herrera',
#  'mangos and mistletoeadriana herrera',
#  'american sweetheartsadriana herrera',
#  'finding joyadriana herrera',
#  'here to stayadriana herrera',
#  'american christmasadriana herrera',
#  'mating the huntresstalia hibbert',
#  'a girl like hertalia hibbert',
#  'untouchabletalia hibbert',
#  'that kind of guytalia hibbert',
#  'work for ittalia hibbert',
#  'get a life, chloe browntalia hibbert',
#  'take a hint, dani browntalia hibbert',
#  'act your age, eve browntalia hibbert',
#  'benefriendschencia c. higgins',
#  'loud and lew’d: a libidinous novelettechencia c. higgins',
#  'holiday honeychencia c. higgins',
#  'glasseschencia c. higgins',
#  'love on the luminouschencia c. higgins',
#  'fast breakerchencia c. higgins',
#  'an illicit seductionchencia c. higgins',
#  'things hoped forchencia c. higgins',
#  'consolation giftschencia c. higgins',
#  'beyond benefriendschencia c. higgins',
#  'dvaughn and kris plan a weddingchencia c. higgins',
#  'last tang standinglauren ho',
#  'the kiss quotienthelen hoang',
#  'the bride testhelen hoang',
#  'the heart principlehelen hoang',
#  'tempted at midnightcheris hodges',
#  'owner of a broken heartcheris hodges',
#  'won’t go home without youcheris hodges',
#  'destination weddingjacqueline j. holness',
#  'thirstymia hopkins',
#  'trashedmia hopkins',
#  'should’ve been: a short storyalexandria house',
#  'set: a novellaalexandria house',
#  'all i want: a christmas shortalexandria house',
#  'new year, new boo?: a holiday shortalexandria house',
#  'jah: a novellaalexandria house',
#  'teach mealexandria house',
#  'shu: a novellaalexandria house',
#  'the love deluxe mixtapealexandria house',
#  'the holiday shorts: a collectionalexandria house',
#  'sweet home highlanderamalie howard',
#  'a lord for the lassamalie howard',
#  'what a scot wantsamalie howard',
#  'the beast of beswickamalie howard',
#  'the princess stakesamalie howard',
#  'rules for heiressesamalie howard',
#  'happiness in jerseyjacinta howard',
#  'finding kennedyjacinta howard',
#  'keeping willowjacinta howard',
#  'loving cassiejacinta howard',
#  'the love below prototype series glimpsesjacinta howard',
#  'the wrong mcelroyk.l. hughes',
#  'a champion’s heartpiper huguley',
#  'the swanpiper huguley',
#  'sweet teapiper huguley',
#  'ties that tetherjane igharo',
#  'the sweetest remedyjane igharo',
#  'a party to murderjohn inman',
#  'larry boots, exterminatorjohn inman',
#  'dilly and bozjohn inman',
#  'always theretiara inserto',
#  'always youtiara inserto',
#  'forget me notbrenda jackson',
#  'his to claimbrenda jackson',
#  'finding home againbrenda jackson',
#  'duty or desirebrenda jackson',
#  'a walk in the parkbrenda jackson',
#  'a catalina cove christmasbrenda jackson',
#  'husband materialbrenda jackson',
#  'entangledbrenda jackson',
#  'the bennetts’ weddingbrenda jackson',
#  'seduced by a steelebrenda jackson',
#  'claimed by a steelebrenda jackson',
#  'the wife he needsbrenda jackson',
#  'follow your heartbrenda jackson',
#  'room for three?katrina jackson',
#  'private eyekatrina jackson',
#  'new year, new wekatrina jackson',
#  'his only valentinekatrina jackson',
#  'bang & burnkatrina jackson',
#  'neighborlykatrina jackson',
#  'grand theft n.y.e.katrina jackson',
#  'every new yearkatrina jackson',
#  'office hourskatrina jackson',
#  'beautiful & dirtykatrina jackson',
#  'insert groom herek.m. jackson',
#  'to me i wedk.m. jackson',
#  'the betting vowk.m. jackson',
#  'romancing the fashionistak.m. jackson',
#  'as good as the first timek.m. jackson',
#  'too sweet to be goodk.m. jackson',
#  'real men knitk.m. jackson',
#  'how to marry keanu reeves in 90 daysk.m. jackson',
#  'the mismatchsara jafari',
#  'ayesha at lastuzma jalaluddin',
#  'hana khan carries onuzma jalaluddin',
#  'the sweetest charadejadesola james',
#  'redeemed by his new york cinderellajadesola james',
#  'anything oncemeka james',
#  'being neighborlymeka james',
#  'the listsmeka james',
#  'being hospitablemeka james',
#  'a real kind of lovebella jay',
#  'a toxic kind of lovebella jay',
#  'a selfish kind of lovebella jay',
#  'rebelbeverly jenkins',
#  'one masked nightbeverly jenkins',
#  'i’ll be home for christmasbeverly jenkins',
#  'on the corner of hope and mainbeverly jenkins',
#  'wild rainbeverly jenkins',
#  'something like lovechristina c. jones',
#  'deuces wildchristina c. jones',
#  'i think i might love youchristina c. jones',
#  'equivalent exchangechristina c. jones',
#  'plus onechristina c. jones',
#  'frosted. whipped. buttered.christina c. jones',
#  'bittersweetchristina c. jones',
#  'wonderchristina c. jones',
#  'press rewindchristina c. jones',
#  'the point of it allchristina c. jones',
#  'collision coursechristina c. jones',
#  'controlled chaoschristina c. jones',
#  'close contactchristina c. jones',
#  'stones of dracontias: the bloodstone dragonn.d. jones',
#  'dragon lore and love: isis and osirisn.d. jones',
#  'crimson hunter: a little red riding hood reimaginingn.d. jones',
#  'of fear and faithn.d. jones',
#  'of beasts and bondsn.d. jones',
#  'the styles of love trilogy: the complete seriesn.d. jones',
#  'unmarriageablesoniah kamal',
#  'dirty & flirtykharma kelley',
#  'pictures from paradisejacki kelly',
#  'fear of datingjacki kelly',
#  'in pursuit of perfectionjacki kelly',
#  'wow!sean kennedy',
#  'come into my worldsean kennedy',
#  'never too latesean kennedy',
#  'the other boyssean kennedy',
#  'tigers on the waysean kennedy',
#  'christmas treatssean kennedy',
#  'the mail order brider. kent',
#  'bearly a ladycassandra khaw',
#  'the millionaire’s clubsandra kitt',
#  'how to be a normal persont.j. klune',
#  'wolfsongt.j. klune',
#  'ravensongt.j. klune',
#  'the bones beneath my skint.j. klune',
#  'blasphemy!t.j. klune',
#  'how to be a movie start.j. klune',
#  'tell me it’s realt.j. klune',
#  'heartsongt.j. klune',
#  'why we fightt.j. klune',
#  'the house in the cerulean seat.j. klune',
#  'brothersongt.j. klune',
#  'under the whispering doort.j. klune',
#  'dating for keepscolleen kwan',
#  'happy endingsthien-kim lam',
#  'it’s gonna be lovemia lansford',
#  'acute reactionsruby lang',
#  'hard knocksruby lang',
#  'clean breaksruby lang',
#  'playing houseruby lang',
#  'open houseruby lang',
#  'house rulesruby lang',
#  'bedding the enemylaquette',
#  'wicked wagerlaquette',
#  'under his protectionlaquette',
#  'jacksonlaquette',
#  'not another family weddingjackie lau',
#  'the ultimate pi day partyjackie lau',
#  'ice cream loverjackie lau',
#  'man vs. durianjackie lau',
#  'a match made for thanksgivingjackie lau',
#  'a second chance road trip for christmasjackie lau',
#  'a fake girlfriend for chinese new yearjackie lau',
#  'pregnant by the playboyjackie lau',
#  'her big city neighborjackie lau',
#  'his grumpy childhood friendjackie lau',
#  'donut fall in lovejackie lau',
#  'temporary wife temptationjayci lee',
#  'a sweet messjayci lee',
#  'off limits attractionjayci lee',
#  'the dating darejayci lee',
#  'finding forever with youkarmen lee',
#  'cups of youkarmen lee',
#  'sips of herkarmen lee',
#  'a taste of honeyrose lerner',
#  'hard sellhudson lin',
#  'the lotus palacejeannie lin',
#  'the jade temptressjeannie lin',
#  'a dance with dangerjeannie lin',
#  'the liar’s dicejeannie lin',
#  'still loving yousheryl lister',
#  'his los angeles surprisesheryl lister',
#  'sweet love/because of yousheryl lister',
#  'spark of desire/all for yousheryl lister',
#  'her christmas wish/designed by lovesheryl lister',
#  'closer to yousheryl lister',
#  'sweet talkin’ lovertracey livesay',
#  'like lovers dotracey livesay',
#  'american royaltytracey livesay',
#  'the demon dukemargaret locke',
#  'lush moneyangelina m. lopez',
#  'hate crushangelina m. lopez',
#  'serving sinangelina m. lopez',
#  'stolen by razelolita lopez',
#  'loveshed: married to the mafiab. love',
#  'yours to haveb. love',
#  'unequivocally, blindly, yoursb. love',
#  'in so deepb. love',
#  'loving a memphis hoodlumb. love',
#  'ain’t no love in his heart: the complete seriesb. love',
#  'brief intermission: a novellab. love',
#  'i need a gangstab. love',
#  'but without hasteb. love',
#  'last chance to loveb. love',
#  None,
#  'the perfect dateevelyn lozada',
#  'gutter rosesjude lucens',
#  'behind these doorsjude lucens',
#  'nasujet lupin',
#  'enraijet lupin',
#  'served with a twistjet lupin',
#  'boracay vowsmaida malby',
#  'new york engagementmaida malby',
#  'singapore flingmaida malby',
#  'samui heatmaida malby',
#  'sofia khan is not obligedayisha malik',
#  'the other half of happinessayisha malik',
#  'bad bloodm. malone',
#  'brazenm. malone',
#  'still brazenm. malone',
#  'royal teasenana malone',
#  'teasing the princessnana malone',
#  'bodyguard to the billionairenana malone',
#  'the billionaire’s secretnana malone',
#  'london royalnana malone',
#  'london soulnana malone',
#  'royal playboynana malone',
#  'playboy’s heartnana malone',
#  'big bennana malone',
#  'the benefactornana malone',
#  'for her benefitnana malone',
#  'east endnana malone',
#  'east boundnana malone',
#  'the fall of eastnana malone',
#  'royal linenana malone',
#  'breaking his rulesaliza mann',
#  'the key to happily ever aftertif marcelo',
#  'i’ll be good to youchelsea maria',
#  'a love so softchelsea maria',
#  'more than a crushchelsea maria',
#  'when the night’s overchelsea maria',
#  'my heart is your secretchelsea maria',
#  'chasing empty heartschelsea maria',
#  'the boy toynicola marsh',
#  'the man bannicola marsh',
#  'interceptedalexa martin',
#  'snappedalexa martin',
#  'how to love metina martin',
#  'weekend fiancetina martin',
#  'for rubytina martin',
#  'when i needed youtina martin',
#  'when you needed metina martin',
#  'just like thatcole mccade',
#  'just like thiscole mccade',
#  'the big towann mcman',
#  'one last stopcasey mcquiston',
#  'the matzah balljean meltzer',
#  'make up break uplily menon (aka sandhya menon)',
#  'bi-sensualnikki michelle',
#  'two wings to fly awaypenny mickelbury',
#  'kenora reinventedhyacinthe miller',
#  'i am justicediana muñoz stewart',
#  'the price of gracediana muñoz stewart',
#  'the edge of obsessiondiana muñoz stewart',
#  'the cost of honordiana muñoz stewart',
#  'hold mecourtney milan',
#  'after the weddingcourtney milan',
#  'the pursuit of…courtney milan',
#  'mrs. martin’s incomparable adventurecourtney milan',
#  'find mecourtney milan',
#  'a compendium of ever-increasing mayhemcourtney milan',
#  'the duke who didn’tcourtney milan',
#  'how to staychristina mitchell',
#  'valentine’s day with a real onetay mo’nae',
#  'rescued by his lovetay mo’nae',
#  'tempted off his lovetay mo’nae',
#  'when love becomes a reasontay mo’nae',
#  'switch’d uptay mo’nae',
#  'please metay mo’nae',
#  'when love becomes a purposetay mo’nae',
#  'dnd: caught up in his lovetay mo’nae',
#  '4 ever down with himtay mo’nae',
#  'eternal lifev.s. nelson',
#  'irrepairableleteisha newton',
#  'cutterleteisha newton',
#  'mangledleteisha newton',
#  'unexpected: a love storyj. nichole',
#  '#futurehusbandj. nichole',
#  'he’s just a friendj. nichole',
#  'a girl like mej. nichole',
#  'only one nightj. nichole',
#  'never him: an enemies to lovers romancej. nichole',
#  'a kiss at midnightj. nichole',
#  'rainbow placejay northcote',
#  'safe placejay northcote',
#  'stuck with youjay northcote',
#  'better placejay northcote',
#  'mud & lacejay northcote',
#  'where love growsjay northcote',
#  'a boyfriend for christmasjay northcote',
#  'no holds barredstephanie nicole norris',
#  'a risqué engagementstephanie nicole norris',
#  'give me a reasonstephanie nicole norris',
#  'a game-changing christmasstephanie nicole norris',
#  'with your permissionstephanie nicole norris',
#  'everlasting desirestephanie nicole norris',
#  'escortstephanie nicole norris',
#  'in pursuit of youstephanie nicole norris',
#  'and this i swearstephanie nicole norris',
#  'move your bodystephanie nicole norris',
#  'cabin feverstephanie nicole norris',
#  'a moment of foreverstephanie nicole norris',
#  'recklessstephanie nicole norris',
#  'however long it takesstephanie nicole norris',
#  'forever my ladystephanie nicole norris',
#  'impromptu seductionstephanie nicole norris',
#  'after the kissstephanie nicole norris',
#  'mark my wordsstephanie nicole norris',
#  'before we say i dostephanie nicole norris',
#  'yours for the takingstephanie nicole norris',
#  'stiffstephanie nicole norris',
#  'his perfect partnerpriscilla oliveras',
#  'her perfect affairpriscilla oliveras',
#  'their perfect melodypriscilla oliveras',
#  'island affairpriscilla oliveras',
#  'holiday home runpriscilla oliveras',
#  'anchored heartspriscilla oliveras',
#  'escapesean ian o’meidhir and connal braginsky',
#  'asking for a friendandi osho',
#  'documenting lighte.e. ottoman',
#  'the doctor’s discretione.e. ottoman',
#  'the craft of lovee.e. ottoman',
#  'a sweet yuletidee.e. ottoman',
#  'the companione.e. ottoman',
#  'the flaw in his marriage plantara pammi',
#  'claiming his bollywood cinderellatara pammi',
#  'the surprise bollywood babytara pammi',
#  'the playboy’s “i do” dealtara pammi',
#  'loathe at first sightsuzanne park',
#  'so we meet againsuzanne park',
#  'the trouble with hating yousajni patel',
#  'first love, take twosajni patel',
#  'blind lovekishaun paul',
#  'the deadly matchkishaun paul',
#  'sweethandn.g. peltier',
#  'to summon nightmaresj.k. pendragon',
#  'sea loverj.k. pendragon',
#  'when katie met cassidycamille perri',
#  'the immortal citymay peterson',
#  'one summer nightcaridad piñeiro',
#  'what happens in summercaridad piñeiro',
#  'never a bridecaridad piñeiro',
#  'south beach lovecaridad piñeiro',
#  'swing batter swingzaida polanco',
#  'crush, interruptedzaida polanco',
#  'extra creditzaida polanco',
#  'mostly sunnyjamie pope',
#  'one warm winterjamie pope',
#  'her night with the dukediana quincy',
#  'the viscount made me do itdiana quincy',
#  'the marriage clockzara raheem',
#  'david and ameenaami rao',
#  'purple lotusveena rao',
#  'hate to want youalisha rai',
#  'wrong to need youalisha rai',
#  'hurts to love youalisha rai',
#  'the right swipealisha rai',
#  'girl gone viralalisha rai',
#  'first comes likealisha rai',
#  'a sister’s secretcydney rax',
#  'a sister’s survivalcydney rax',
#  'a sister’s powercydney rax',
#  'be my lightari reavis',
#  'just fake itari reavis',
#  'all the pieces of youari reavis',
#  'never leave your sideari reavis',
#  'the write escapecharish reid',
#  'hearts on holdcharish reid',
#  'once upon a dukeerica ridley',
#  'kiss of a dukeerica ridley',
#  'wish upon a dukeerica ridley',
#  'never say dukeerica ridley',
#  'dukes, actuallyerica ridley',
#  'the dukes brideerica ridley',
#  'the dukes embraceerica ridley',
#  'the dukes desireerica ridley',
#  'dawn with a dukeerica ridley',
#  'one night with a dukeerica ridley',
#  'ten days with a dukeerica ridley',
#  'forever your dukeerica ridley',
#  'the bittersweet bridevanessa riley',
#  'the bashful bridevanessa riley',
#  'the butterfly bridevanessa riley',
#  'the bewildered bridevanessa riley',
#  'a duke, the lady, and a babyvanessa riley',
#  'an earl, the girl, and a toddlervanessa riley',
#  'the love studykris ripper',
#  'must love booksshauna robinson',
#  'cherish mefarrah rochon',
#  'return to mefarrah rochon',
#  'christmas kissesfarrah rochon',
#  'the boyfriend projectfarrah rochon',
#  'the dating playbookfarrah rochon',
#  'honey girlmorgan rogers',
#  'mistletoe in juneaudahlia rose',
#  'loving yasmineana e. ross',
#  'desire’s chaseana e. ross',
#  'pleasing mindyana e. ross',
#  'playing the palacepaul rudnick',
#  'every last breathjuno rushdan',
#  'nothing to fearjuno rushdan',
#  'secret hungersatin russell',
#  'secret needsatin russell',
#  'secret giftssatin russell',
#  'long shotkennedy ryan',
#  'block shotkennedy ryan',
#  'hoops holidaykennedy ryan',
#  'hook shotkennedy ryan',
#  'the kingmakerkennedy ryan',
#  'the rebel kingkennedy ryan',
#  'queen movekennedy ryan',
#  'engaging the enemyreese ryan',
#  'off limits loversreese ryan',
#  'seduced by second chancesreese ryan',
#  'the rival bidreese ryan',
#  'secret heir seductionreese ryan',
#  'a reunion of rivalsreese ryan',
#  'second chance on cypress lanereese ryan',
#  'reelreese ryan',
#  'mvp daddyk. sadeé',
#  'hot 16k. sadeé',
#  'alternate endingsk. sadeé',
#  'my funny valentineblue saffire',
#  'be my valentineblue saffire',
#  'doctor feel goodblue saffire',
#  'when to call quinnblue saffire',
#  'in deepblue saffire',
#  'dirty tacticsemma salah',
#  'the infamous miss rodriguezlydia san andres',
#  'a summer for scandallydia san andres',
#  'heartbeat bravespamela sanderson',
#  'lovesick bravespamela sanderson',
#  'sweetheart bravespamela sanderson',
#  'crooked rock bravespamela sanderson',
#  'a taste of sageyaffa s. santos',
#  'how to lovesabrina b. scales',
#  'thou shall not runsabrina b. scales',
#  'naughty: an erotic christmas novellasabrina b. scales',
#  'nastysabrina b. scales',
#  'plussabrina b. scales',
#  'freaky talessabrina b. scales',
#  'desdemona’s closet: a christmas talesabrina b. scales',
#  'thou shall not hidesabrina b. scales',
#  'thou shall not fearsabrina b. scales',
#  'unmasked by the marquesscat sebastian',
#  'a duke in disguisecat sebastian',
#  'a little light mischiefcat sebastian',
#  'a delicate deceptioncat sebastian',
#  'hither, pagecat sebastian',
#  'two rogues make a rightcat sebastian',
#  'femme tales: a modern day fairy tale trilogyanne shade',
#  'love and lotus blossomsanne shade',
#  'the takeover effectnisha sharma',
#  'the legal affairnisha sharma',
#  'dating dr. dilnisha sharma',
#  'then, now, alwaysmona shroff',
#  'then there was youmona shroff',
#  'a tiny piece of something greaterjude sierra',
#  'death’s dancerjasmine silvera',
#  'dancer’s flamejasmine silvera',
#  'the talon & the bladejasmine silvera',
#  'binding shadowsjasmine silvera',
#  'lean on mepat simmons',
#  'here for youpat simmons',
#  'christmas dinnerpat simmons',
#  'stand by mepat simmons',
#  'sin & inknaima simone',
#  'the billionaire’s bargainnaima simone',
#  'black tie billionairenaima simone',
#  'blame it on the billionairenaima simone',
#  'ruthless pridenaima simone',
#  'trust fund fiancénaima simone',
#  'vows in name onlynaima simone',
#  'back in the texan’s bednaima simone',
#  'slow dance at rose bendnaima simone',
#  'the road to rose bendnaima simone',
#  'secrets of a one night standnaima simone',
#  'christmas at rose bendnaima simone',
#  'archangel’s warnalini singh',
#  'wolf nightnalini singh',
#  'love hardnalini singh',
#  'alpha nightnalini singh',
#  'all things burnjodie slaughter',
#  'white whiskey bargainjodie slaughter',
#  'just one more: a valentine’s day novellajodie slaughter',
#  'in case you forgotfrederick smith and chaz lamar cruz',
#  'busy ain’t the half of itfrederick smith and chaz lamar cruz',
#  'wicked gamesmaureen smith',
#  'the swedemaureen smith',
#  'sin binmaureen smith',
#  'tikka chance on mesuleikha snyder',
#  'dil or no dilsuleikha snyder',
#  'big bad wolfsuleikha snyder',
#  'pretty little lionsuleikha snyder',
#  'one night more: a hotel arroyo novellasabrina sol',
#  'hot holiday lovegermaine solomon',
#  'pretending he’s minemia sosa',
#  'crashing into hermia sosa',
#  'the worst best manmia sosa',
#  'deception and chaoss.m. soto',
#  'blood and chaoss.m. soto',
#  'a cruel loves.m. soto',
#  'love and chaoss.m. soto',
#  'aches.m. soto',
#  'kiss me with liess.m. soto',
#  'at the ceo’s pleasureyarah st. john',
#  'his marriage demandyarah st. john',
#  'red carpet redemptionyarah st. john',
#  'secrets of a fake fiancéeyarah st. john',
#  'insatiable hungeryarah st. john',
#  'best laid plansella stainton',
#  'love and loopholesrailyn stone',
#  'restored heartsrailyn stone',
#  'there galapagos my heartphilip william stover',
#  'the hideaway innphilip william stover',
#  'the beautiful things shoppephilip william stover',
#  'dial a for auntiesjesse q. sutanto',
#  'jiltedlilah suzanne',
#  'tack & jibelilah suzanne',
#  'moon-bright tidesroanna sylver',
#  'bound to libertykiru taye',
#  'honeydews. taylor',
#  'i’m yourss. taylor',
#  'september songs. taylor',
#  'a family for the firefighterjacquelin thomas',
#  'her hometown herojacquelin thomas',
#  'the heart is a universesherry thomas',
#  'chasing starsalex k. thorne',
#  'the donut trapjulie tieu',
#  'cosmic desirechrista tomlinson',
#  'blaze: a superhero romancechrista tomlinson',
#  'cuffs, collars, and love: the complete serieschrista tomlinson',
#  'valentines day herochrista tomlinson',
#  'dr. z: a superhero romancechrista tomlinson',
#  'beast: a superhero romancechrista tomlinson',
#  'frost: a superhero romancechrista tomlinson',
#  'writing her inholley trent',
#  'three part harmonyholley trent',
#  'lowdown dirtyholley trent',
#  'plot twistholley trent',
#  'top of her gamem. ullrich',
#  'the kyriakis redemptioneve vaughn',
#  'obsessedeve vaughn',
#  'perfecteve vaughn',
#  'the kyriakis triumpheve vaughn',
#  'temptedeve vaughn',
#  'bishopa.e. via',
#  'nothing special vii: ex meridiana.e. via',
#  'wooda.e. via',
#  'cure for insomnialaina villeneuve',
#  'by chancediana w.',
#  'chance takendiana w.',
#  'chance givendiana w.',
#  'feelin’ youdiana w.',
#  'the lady’s guide to celestial mechanicsolivia waite',
#  'the care and feeding of waspish widowsolivia waite',
#  'the hellion’s waltzolivia waite',
#  'tailor-madeyolanda wallace',
#  'pleasure cruiseyolanda wallace',
#  'comrade cowgirlyolanda wallace',
#  'heart of a killeryolanda wallace',
#  'displacement: a building 402 novellaalexandra warren',
#  'a tale of two cities: a valentine’s novellaalexandra warren',
#  'a tale of two cities: holiday novella collectionalexandra warren',
#  'baggage claimedalexandra warren',
#  'one last shotalexandra warren',
#  'love unsolicitedalexandra warren',
#  'uncovered truthsalexandra warren',
#  'oops!alexandra warren',
#  'whoaalexandra warren',
#  'seductive memoryaltonya washington',
#  'seductive momentsaltonya washington',
#  'the warrior’s giftaltonya washington',
#  'at her feetrebekah weatherspoon',
#  'rafe: a buff male nannyrebekah weatherspoon',
#  'xeni: a marriage of inconveniencerebekah weatherspoon',
#  'a cowboy to rememberrebekah weatherspoon',
#  'if the boot fitsrebekah weatherspoon',
#  'a thorn in the saddlerebekah weatherspoon',
#  'before we say goodbyej.n. welsh',
#  'in tunej.n. welsh',
#  'in rhythmj.n. welsh',
#  'make the playjamie wesley',
#  'the sweet lifejamie wesley',
#  'nine of swords, reversedxan west',
#  'their troublesome crushxan west',
#  'eight kinky nightsxan west',
#  'tendernessxan west',
#  'love at the icicle cafédenise n. wheatley',
#  'she gets what she wantsdenise n. wheatley',
#  'cold case true crimedenise n. wheatley',
#  'bayou christmas disappearancedenise n. wheatley',
#  'how to fail at flirtingdenise williams',
#  'the fastest way to falldenise williams',
#  'the man i can’t haveshanora williams',
#  'the man i needshanora williams',
#  'coach meshanora williams',
#  'until the last breathshanora williams',
#  'forbidden promisessynithia williams',
#  'scandalous secretssynithia williams',
#  ...]

# %%
new_title_string = str([str(x).lstrip('\'') for x in title_string]).strip("[]")

# %%
new_title_string
# Out:
# '\'the wolf at the doorcharlie adhara\', \'the wolf at baycharlie adhara\', \'thrown to the wolvescharlie adhara\', \'wolf in sheep’s clothingcharlie adhara\', \'his bewildered matebrea alepoú\', \'never trust a porn starbrea alepoú\', \'finding mr. clausbrea alepoú\', \'a king to be protected: gay harembrea alepoú\', \'their blood: mmmmm dark paranormal romancebrea alepoú\', \'his royal matebrea alepoú\', \'his apprehensive matebrea alepoú\', \'inconvenient attachments: dark mmm paranormal romancebrea alepoú\', \'his runaway matebrea alepoú\', \'love for all timekianna alexander\', \'couldn’t ask for morekianna alexander\', \'forever with you & the sweet taste of seductionkianna alexander\', \'then came you & written with lovekianna alexander\', \'never let me gokianna alexander\', \'the wedding secretkianna alexander\', \'after hours redemptionkianna alexander\', \'after hours attractionkianna alexander\', \'the long hot summerrochelle alers\', \'the only manrochelle alers\', \'the bridal suiterochelle alers\', \'second-chance sweet shoprochelle alers\', \'starting over in wickham fallsrochelle alers\', \'the seaside caferochelle alers\', \'the beach houserochelle alers\', \'tell-taledanielle allen\', \'v is for villainousdanielle allen\', \'v is for vengefuldanielle allen\', \'annabelle and leedanielle allen\', \'slow news day: a groundhog day hot holiday hookupdanielle allen\', \'fool in love: an april fool’s day hot holiday hookupdanielle allen\', \'trouble’s what you’re indanielle allen\', \'the legacydylan allen\', \'the sun and her stardylan allen\', \'the legenddylan allen\', \'between now and foreverdylan allen\', \'the jezebeldylan allen\', \'see memichelle arris\', \'lover’s bida.c. arthur\', \'a cougar’s kissa.c. arthur\', \'awaken the dragona.c. arthur\', \'office policya.c. arthur\', \'corporate seductiona.c. arthur\', \'laws of attractiona.c. arthur\', \'a private affaira.c. arthur\', \'roarka.c. arthur\', \'claim the dragona.c. arthur\', \'at your servicea.c. arthur\', \'the last affaira.c. arthur\', \'call the coroneravril ashton\', \'kiss your scarsavril ashton\', \'dig your graveavril ashton\', \'remember meavril ashton\', \'make me stayamarie avant\', \'the weddingamarie avant\', \'neverjoy avery\', \'maybejoy avery\', \'alwaysjoy avery\', \'a bid on foreverjoy avery\', \'forever with you & the sweet taste of seductionjoy avery\', \'then came you & written with lovejoy avery\', \'14 days & other storiesola awonubi\', \'when frankie meets johnnyxio axelrod\', \'honey & spicebolu babalola\', \'christmas in evergreen: bells are ringinglacey baker\', \'grey dawn: a tale of abolition and unionnyri bakkalian\', \'rescue mecheryl barton\', \'true lies or true lovecheryl barton\', \'she said nocheryl barton\', \'swagger and baggagecheryl barton\', \'release mecheryl barton\', \'dashing through the snowcheryl barton\', \'claiming his childcheryl barton\', \'always bet on blackcheryl barton\', \'destination weddingdiksha basu\', \'second chance with her billionairetherese beharrie\', \'from heiress to momtherese beharrie\', \'island fling with the tycoontherese beharrie\', \'her twin baby secrettherese beharrie\', \'one last chancetherese beharrie\', \'marrying his runaway heiresstherese beharrie\', \'his princess by christmastherese beharrie\', \'when worlds collidemillie belizaire\', \'when hearts collidemillie belizaire\', \'when souls collidemillie belizaire\', \'holiday surprisemillie belizaire\', \'the garden of edenmillie belizaire\', \'written in the starsalexandria bellefleur\', \'hang the moonalexandria bellefleur\', \'count your lucky starsalexandria bellefleur\', \'he who is a friendlove belvin\', \'he who is a loverlove belvin\', \'he who is a protectorlove belvin\', \'the rules of arrangementanisha bhatia\', \'blessedmaggie blackbird\', \'redeemedmaggie blackbird\', \'sanctifiedmaggie blackbird\', \'tied up with a bowmaggie blackbird\', \'thanks to youmaggie blackbird\', \'renewedmaggie blackbird\', \' ...

# %%
try:
    query = """\
    SELECT
    b.best_title AS title,
    REPLACE(SPLIT_PART(SPLIT_PART(b.best_author,' (',1),', ',2),'.','')||' '||SPLIT_PART(b.best_author,', ',1) AS author,
    SUBSTRING(i.location_code FROM 1 FOR 3) AS location,
    CASE
    WHEN COUNT(i.id) != 0 THEN TRUE
    ELSE FALSE
    END AS owns
    FROM
    sierra_view.bib_record_property b
    JOIN
    sierra_view.bib_record_item_record_link l
    ON
    b.bib_record_id = l.bib_record_id
    JOIN
    sierra_view.item_record i
    ON
    l.item_record_id = i.id
    WHERE
    b.material_code = 'a'
    AND lower(b.best_title)||LOWER(REPLACE(SPLIT_PART(SPLIT_PART(b.best_author,' (',1),', ',2),'.','')||' '||SPLIT_PART(b.best_author,', ',1)) IN ("""\
    +new_title_string+"""\
    )
    AND b.publish_year >= 2018

    GROUP BY 1,2,3
    ORDER BY 1,2,3
    """
    #variable connection string should be defined in the imported config file
    conn = psycopg2.connect( config['db']['connection_string'] )
except:
    print("unable to connect to the database")
    clear_connection()
cursor = conn.cursor()
cursor.execute(query)
#For now, just storing the data in a variable. We'll use it later.
sierra_rows = cursor.fetchall()
conn.close()

# %%
sierra_rows
# Out:
# [('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'act', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'ar2', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'arl', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'ash', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'bed', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'br2', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'brk', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'ca8', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'ca9', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'cam', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'co2', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'con', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'dd2', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'ddm', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'dov', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'fp2', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'fpl', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'frk', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'lex', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'lin', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'med', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'nat', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'nee', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'nor', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'ntn', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'so3', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'som', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'wat', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'wel', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'win', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'wlm', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'wob', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'wsn', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'wwd', True),
#  ('10 minutes 38 seconds in this strange world', 'Elif Shafak', 'wyl', True),
#  ('100 boyfriends', 'Brontez Purnell', 'arl', True),
#  ('100 boyfriends', 'Brontez Purnell', 'ash', True),
#  ('100 boyfriends', 'Brontez Purnell', 'brk', True),
#  ('100 boyfriends', 'Brontez Purnell', 'ca5', True),
#  ('100 boyfriends', 'Brontez Purnell', 'ca9', True),
#  ('100 boyfriends', 'Brontez Purnell', 'cam', True),
#  ('100 boyfriends', 'Brontez Purnell', 'dov', True),
#  ('100 boyfriends', 'Brontez Purnell', 'lex', True),
#  ('100 boyfriends', 'Brontez Purnell', 'nee', True),
#  ('100 boyfriends', 'Brontez Purnell', 'ntn', True),
#  ('100 boyfriends', 'Brontez Purnell', 'som', True),
#  ('100 boyfriends', 'Brontez Purnell', 'sud', True),
#  ('100 boyfriends', 'Brontez Purnell', 'wat', True),
#  ('13th balloon', 'Mark Bibbins', 'ca9', True),
#  ('13th balloon', 'Mark Bibbins', 'cam', True),
#  ('13th balloon', 'Mark Bibbins', 'wel', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'arl', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'bed', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'br2', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'brk', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'ca9', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'cam', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'con', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'fp2', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'fpl', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'frk', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'lin', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'nat', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'nee', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'nor', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'ntn', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'wat', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'win', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'wlm', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'wob', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'wsn', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'wwd', True),
#  ('99 nights in Logar', 'Jamil Jan Kochai', 'wyl', True),
#  ('99 ways to die', 'Ed Lin', 'ash', True),
#  ('99 ways to die', 'Ed Lin', 'bed', True),
#  ('99 ways to die', 'Ed Lin', 'frk', True),
#  ('99 ways to die', 'Ed Lin', 'lex', True),
#  ('99 ways to die', 'Ed Lin', 'lin', True),
#  ('99 ways to die', 'Ed Lin', 'may', True),
#  ('99 ways to die', 'Ed Lin', 'med', True),
#  ('99 ways to die', 'Ed Lin', 'nat', True),
#  ('99 ways to die', 'Ed Lin', 'ntn', True),
#  ('99 ways to die', 'Ed Lin', 'sud', True),
#  ('99 ways to die', 'Ed Lin', 'wel', True),
#  ('99 ways to die', 'Ed Lin', 'win', True),
#  ('99 ways to die', 'Ed Lin', 'wsn', True),
#  ('99 ways to die', 'Ed Lin', 'wyl', True),
#  ('A beginning at the end', 'Mike Chen', 'act', True),
#  ('A beginning at the end', 'Mike Chen', 'ash', True),
#  ('A beginning at the end', 'Mike Chen', 'bed', True),
#  ('A beginning at the end', 'Mike Chen', 'blm', True),
#  ('A beginning at the end', 'Mike Chen', 'brk', True),
#  ('A beginning at the end', 'Mike Chen', 'cam', True),
#  ('A beginning at the end', 'Mike Chen', 'co2', True),
#  ('A beginning at the end', 'Mike Chen', 'con', True),
#  ('A beginning at the end', 'Mike Chen', 'frk', True),
#  ('A beginning at the end', 'Mike Chen', 'lex', True),
#  ('A beginning at the end', 'Mike Chen', 'lin', True),
#  ('A beginning at the end', 'Mike Chen', 'med', True),
#  ('A beginning at the end', 'Mike Chen', 'nat', True),
#  ('A beginning at the end', 'Mike Chen', 'nee', True),
#  ('A beginning at the end', 'Mike Chen', 'nor', True),
#  ('A beginning at the end', 'Mike Chen', 'ntn', True),
#  ('A beginning at the end', 'Mike Chen', 'so3', True),
#  ('A beginning at the end', 'Mike Chen', 'som', True),
#  ('A beginning at the end', 'Mike Chen', 'sud', True),
#  ('A beginning at the end', 'Mike Chen', 'wel', True),
#  ('A beginning at the end', 'Mike Chen', 'wlm', True),
#  ('A beginning at the end', 'Mike Chen', 'wob', True),
#  ('A beginning at the end', 'Mike Chen', 'wsn', True),
#  ('A beginning at the end', 'Mike Chen', 'wwd', True),
#  ('A beginning at the end', 'Mike Chen', 'wyl', True),
#  ('A burning', 'Megha Majumdar', 'ac2', True),
#  ('A burning', 'Megha Majumdar', 'act', True),
#  ('A burning', 'Megha Majumdar', 'ar2', True),
#  ('A burning', 'Megha Majumdar', 'arl', True),
#  ('A burning', 'Megha Majumdar', 'ash', True),
#  ('A burning', 'Megha Majumdar', 'bed', True),
#  ('A burning', 'Megha Majumdar', 'blm', True),
#  ('A burning', 'Megha Majumdar', 'br2', True),
#  ('A burning', 'Megha Majumdar', 'br3', True),
#  ('A burning', 'Megha Majumdar', 'brk', True),
#  ('A burning', 'Megha Majumdar', 'ca4', True),
#  ('A burning', 'Megha Majumdar', 'ca5', True),
#  ('A burning', 'Megha Majumdar', 'ca6', True),
#  ('A burning', 'Megha Majumdar', 'ca7', True),
#  ('A burning', 'Megha Majumdar', 'ca8', True),
#  ('A burning', 'Megha Majumdar', 'ca9', True),
#  ('A burning', 'Megha Majumdar', 'cam', True),
#  ('A burning', 'Megha Majumdar', 'co2', True),
#  ('A burning', 'Megha Majumdar', 'con', True),
#  ('A burning', 'Megha Majumdar', 'dd2', True),
#  ('A burning', 'Megha Majumdar', 'ddm', True),
#  ('A burning', 'Megha Majumdar', 'dov', True),
#  ('A burning', 'Megha Majumdar', 'fp2', True),
#  ('A burning', 'Megha Majumdar', 'fpl', True),
#  ('A burning', 'Megha Majumdar', 'frk', True),
#  ('A burning', 'Megha Majumdar', 'fst', True),
#  ('A burning', 'Megha Majumdar', 'hol', True),
#  ('A burning', 'Megha Majumdar', 'lex', True),
#  ('A burning', 'Megha Majumdar', 'lin', True),
#  ('A burning', 'Megha Majumdar', 'may', True),
#  ('A burning', 'Megha Majumdar', 'med', True),
#  ('A burning', 'Megha Majumdar', 'mil', True),
#  ('A burning', 'Megha Majumdar', 'mld', True),
#  ('A burning', 'Megha Majumdar', 'na2', True),
#  ('A burning', 'Megha Majumdar', 'na3', True),
#  ('A burning', 'Megha Majumdar', 'nat', True),
#  ('A burning', 'Megha Majumdar', 'nee', True),
#  ('A burning', 'Megha Majumdar', 'nor', True),
#  ('A burning', 'Megha Majumdar', 'ntn', True),
#  ('A burning', 'Megha Majumdar', 'shr', True),
#  ('A burning', 'Megha Majumdar', 'so2', True),
#  ('A burning', 'Megha Majumdar', 'so3', True),
#  ('A burning', 'Megha Majumdar', 'som', True),
#  ('A burning', 'Megha Majumdar', 'sto', True),
#  ('A burning', 'Megha Majumdar', 'wat', True),
#  ('A burning', 'Megha Majumdar', 'we2', True),
#  ('A burning', 'Megha Majumdar', 'wel', True),
#  ('A burning', 'Megha Majumdar', 'win', True),
#  ('A burning', 'Megha Majumdar', 'wlm', True),
#  ('A burning', 'Megha Majumdar', 'wob', True),
#  ('A burning', 'Megha Majumdar', 'wsn', True),
#  ('A burning', 'Megha Majumdar', 'ww2', True),
#  ('A burning', 'Megha Majumdar', 'wwd', True),
#  ('A burning', 'Megha Majumdar', 'wyl', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'blm', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'br2', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'br3', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'brk', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'cam', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'frk', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'lex', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'med', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'som', True),
#  ('A cowboy to remember', 'Rebekah Weatherspoon', 'wlm', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'arl', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'ash', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'bed', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'blm', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'brk', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'ca4', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'cam', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'con', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'fp2', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'fpl', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'frk', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'lex', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'med', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'nee', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'nor', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'ntn', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'wat', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'wel', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'win', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'wlm', True),
#  ('A deadly divide', 'Ausma Zehanat Khan', 'wyl', True),
#  ('A deadly inside scoop', 'Abby Collette', 'arl', True),
#  ('A deadly inside scoop', 'Abby Collette', 'blm', True),
#  ('A deadly inside scoop', 'Abby Collette', 'br2', True),
#  ('A deadly inside scoop', 'Abby Collette', 'brk', True),
#  ('A deadly inside scoop', 'Abby Collette', 'cam', True),
#  ('A deadly inside scoop', 'Abby Collette', 'fpl', True),
#  ('A deadly inside scoop', 'Abby Collette', 'lex', True),
#  ('A deadly inside scoop', 'Abby Collette', 'nee', True),
#  ('A deadly inside scoop', 'Abby Collette', 'nor', True),
#  ('A deadly inside scoop', 'Abby Collette', 'ntn', True),
#  ('A deadly inside scoop', 'Abby Collette', 'som', True),
#  ('A deadly inside scoop', 'Abby Collette', 'sto', True),
#  ('A deadly inside scoop', 'Abby Collette', 'wat', True),
#  ('A deadly inside scoop', 'Abby Collette', 'wel', True),
#  ('A deadly inside scoop', 'Abby Collette', 'win', True),
#  ('A deadly inside scoop', 'Abby Collette', 'wob', True),
#  ('A deadly inside scoop', 'Abby Collette', 'wsn', True),
#  ('A delicate deception', 'Cat Sebastian', 'br2', True),
#  ('A delicate deception', 'Cat Sebastian', 'brk', True),
#  ('A delicate deception', 'Cat Sebastian', 'nat', True),
#  ('A desolation called peace', 'Arkady Martine', 'act', True),
#  ('A desolation called peace', 'Arkady Martine', 'ar2', True),
#  ('A desolation called peace', 'Arkady Martine', 'arl', True),
#  ('A desolation called peace', 'Arkady Martine', 'bed', True),
#  ('A desolation called peace', 'Arkady Martine', 'blm', True),
#  ('A desolation called peace', 'Arkady Martine', 'brk', True),
#  ('A desolation called peace', 'Arkady Martine', 'ca5', True),
#  ('A desolation called peace', 'Arkady Martine', 'ca8', True),
#  ('A desolation called peace', 'Arkady Martine', 'cam', True),
#  ('A desolation called peace', 'Arkady Martine', 'con', True),
#  ('A desolation called peace', 'Arkady Martine', 'fpl', True),
#  ('A desolation called peace', 'Arkady Martine', 'lex', True),
#  ('A desolation called peace', 'Arkady Martine', 'lin', True),
#  ('A desolation called peace', 'Arkady Martine', 'may', True),
#  ('A desolation called peace', 'Arkady Martine', 'mld', True),
#  ('A desolation called peace', 'Arkady Martine', 'mwy', True),
#  ('A desolation called peace', 'Arkady Martine', 'nee', True),
#  ('A desolation called peace', 'Arkady Martine', 'ntn', True),
#  ('A desolation called peace', 'Arkady Martine', 'oln', True),
#  ('A desolation called peace', 'Arkady Martine', 'so2', True),
#  ('A desolation called peace', 'Arkady Martine', 'som', True),
#  ('A desolation called peace', 'Arkady Martine', 'sud', True),
#  ('A desolation called peace', 'Arkady Martine', 'wat', True),
#  ('A desolation called peace', 'Arkady Martine', 'wel', True),
#  ('A desolation called peace', 'Arkady Martine', 'win', True),
#  ('A desolation called peace', 'Arkady Martine', 'wlm', True),
#  ('A desolation called peace', 'Arkady Martine', 'wyl', True),
#  ('A duke by default', 'Alyssa Cole', 'act', True),
#  ('A duke by default', 'Alyssa Cole', 'ar2', True),
#  ('A duke by default', 'Alyssa Cole', 'arl', True),
#  ('A duke by default', 'Alyssa Cole', 'ash', True),
#  ('A duke by default', 'Alyssa Cole', 'blm', True),
#  ('A duke by default', 'Alyssa Cole', 'brk', True),
#  ('A duke by default', 'Alyssa Cole', 'cam', True),
#  ('A duke by default', 'Alyssa Cole', 'fpl', True),
#  ('A duke by default', 'Alyssa Cole', 'frk', True),
#  ('A duke by default', 'Alyssa Cole', 'lex', True),
#  ('A duke by default', 'Alyssa Cole', 'ntn', True),
#  ('A duke by default', 'Alyssa Cole', 'som', True),
#  ('A duke by default', 'Alyssa Cole', 'wat', True),
#  ('A duke by default', 'Alyssa Cole', 'wlm', True),
#  ('A duke by default', 'Alyssa Cole', 'wsn', True),
#  ('A duke by default', 'Alyssa Cole', 'wwd', True),
#  ('A duke by default', 'Alyssa Cole', 'wyl', True),
#  ('A duke in disguise', 'Cat Sebastian', 'br2', True),
#  ('A duke in disguise', 'Cat Sebastian', 'brk', True),
#  ('A duke in disguise', 'Cat Sebastian', 'nee', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'ash', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'blm', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'brk', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'cam', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'lex', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'nat', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'nee', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'ntn', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'som', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'win', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'wsn', True),
#  ('A duke, the lady, and a baby', 'Vanessa Riley', 'wwd', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'bed', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'blm', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'brk', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'cam', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'fpl', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'frk', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'lex', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'lin', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'nor', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'ntn', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'som', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'wat', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'wel', True),
#  ('A fortune for your disaster', 'Hanif Abdurraqib', 'wlm', True),
#  ('A game of cones', 'Abby Collette', 'arl', True),
#  ('A game of cones', 'Abby Collette', 'brk', True),
#  ('A game of cones', 'Abby Collette', 'ca5', True),
#  ('A game of cones', 'Abby Collette', 'cam', True),
#  ('A game of cones', 'Abby Collette', 'fpl', True),
#  ('A game of cones', 'Abby Collette', 'lex', True),
#  ('A game of cones', 'Abby Collette', 'nee', True),
#  ('A game of cones', 'Abby Collette', 'ntn', True),
#  ('A game of cones', 'Abby Collette', 'som', True),
#  ('A game of cones', 'Abby Collette', 'sud', True),
#  ('A game of cones', 'Abby Collette', 'wat', True),
#  ('A game of cones', 'Abby Collette', 'wel', True),
#  ('A game of cones', 'Abby Collette', 'wlm', True),
#  ('A game of cones', 'Abby Collette', 'wob', True),
#  ('A game of cones', 'Abby Collette', 'wsn', True),
#  ('A game of cones', 'Abby Collette', 'wwd', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'arl', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'ash', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'bed', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'br2', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'brk', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'ca4', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'ca5', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'ca9', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'cam', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'con', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'ddm', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'dov', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'fpl', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'lex', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'may', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'med', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'mil', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'mld', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'nee', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'nor', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'ntn', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'so2', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'som', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'sto', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'wat', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'wel', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'win', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'wlm', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'wob', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'wsn', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'wwd', True),
#  ('A girl is a body of water', 'Jennifer Nansubuga Makumbi', 'wyl', True),
#  ('A girl like her', 'Talia Hibbert', 'med', True),
#  ('A glimmer of death', 'Valerie Wilson Wesley', 'lex', True),
#  ('A glimmer of death', 'Valerie Wilson Wesley', 'ntn', True),
#  ('A glimmer of death', 'Valerie Wilson Wesley', 'wat', True),
#  ('A glimmer of death', 'Valerie Wilson Wesley', 'wob', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'arl', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'brk', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'ca9', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'cam', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'lex', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'nor', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'ntn', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'som', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'wel', True),
#  ('A history of my brief body', 'Billy-Ray Belcourt', 'wlm', True),
#  ('A house divided', 'Sulari Gentill', 'bed', True),
#  ('A house divided', 'Sulari Gentill', 'blm', True),
#  ('A house divided', 'Sulari Gentill', 'cam', True),
#  ('A house divided', 'Sulari Gentill', 'med', True),
#  ('A house divided', 'Sulari Gentill', 'wat', True),
#  ('A hundred suns', 'Karin Tanabe', 'arl', True),
#  ('A hundred suns', 'Karin Tanabe', 'blm', True),
#  ('A hundred suns', 'Karin Tanabe', 'br2', True),
#  ('A hundred suns', 'Karin Tanabe', 'brk', True),
#  ('A hundred suns', 'Karin Tanabe', 'cam', True),
#  ('A hundred suns', 'Karin Tanabe', 'frk', True),
#  ('A hundred suns', 'Karin Tanabe', 'lin', True),
#  ('A hundred suns', 'Karin Tanabe', 'med', True),
#  ('A hundred suns', 'Karin Tanabe', 'mld', True),
#  ('A hundred suns', 'Karin Tanabe', 'nat', True),
#  ('A hundred suns', 'Karin Tanabe', 'nee', True),
#  ('A hundred suns', 'Karin Tanabe', 'nor', True),
#  ('A hundred suns', 'Karin Tanabe', 'ntn', True),
#  ('A hundred suns', 'Karin Tanabe', 'sud', True),
#  ('A hundred suns', 'Karin Tanabe', 'wat', True),
#  ('A hundred suns', 'Karin Tanabe', 'win', True),
#  ('A hundred suns', 'Karin Tanabe', 'wlm', True),
#  ('A hundred suns', 'Karin Tanabe', 'wob', True),
#  ('A hundred suns', 'Karin Tanabe', 'wsn', True),
#  ('A hundred suns', 'Karin Tanabe', 'wwd', True),
#  ('A hundred suns', 'Karin Tanabe', 'wyl', True),
#  ('A jazz funeral for Uncle Tom', 'Harmony Holiday', 'blm', True),
#  ('A jazz funeral for Uncle Tom', 'Harmony Holiday', 'may', True),
#  ('A jazz funeral for Uncle Tom', 'Harmony Holiday', 'wel', True),
#  ('A madness of sunshine', 'Nalini Singh', 'act', True),
#  ('A madness of sunshine', 'Nalini Singh', 'arl', True),
#  ('A madness of sunshine', 'Nalini Singh', 'ash', True),
#  ('A madness of sunshine', 'Nalini Singh', 'bed', True),
#  ('A madness of sunshine', 'Nalini Singh', 'blm', True),
#  ('A madness of sunshine', 'Nalini Singh', 'br2', True),
#  ('A madness of sunshine', 'Nalini Singh', 'brk', True),
#  ('A madness of sunshine', 'Nalini Singh', 'ca8', True),
#  ('A madness of sunshine', 'Nalini Singh', 'ca9', True),
#  ('A madness of sunshine', 'Nalini Singh', 'cam', True),
#  ('A madness of sunshine', 'Nalini Singh', 'co2', True),
#  ('A madness of sunshine', 'Nalini Singh', 'con', True),
#  ('A madness of sunshine', 'Nalini Singh', 'fp2', True),
#  ('A madness of sunshine', 'Nalini Singh', 'fpl', True),
#  ('A madness of sunshine', 'Nalini Singh', 'frk', True),
#  ('A madness of sunshine', 'Nalini Singh', 'lex', True),
#  ('A madness of sunshine', 'Nalini Singh', 'lin', True),
#  ('A madness of sunshine', 'Nalini Singh', 'may', True),
#  ('A madness of sunshine', 'Nalini Singh', 'med', True),
#  ('A madness of sunshine', 'Nalini Singh', 'mil', True),
#  ('A madness of sunshine', 'Nalini Singh', 'mwy', True),
#  ('A madness of sunshine', 'Nalini Singh', 'na2', True),
#  ('A madness of sunshine', 'Nalini Singh', 'nat', True),
#  ('A madness of sunshine', 'Nalini Singh', 'nee', True),
#  ('A madness of sunshine', 'Nalini Singh', 'nor', True),
#  ('A madness of sunshine', 'Nalini Singh', 'ntn', True),
#  ('A madness of sunshine', 'Nalini Singh', 'so2', True),
#  ('A madness of sunshine', 'Nalini Singh', 'som', True),
#  ('A madness of sunshine', 'Nalini Singh', 'sto', True),
#  ('A madness of sunshine', 'Nalini Singh', 'sud', True),
#  ('A madness of sunshine', 'Nalini Singh', 'wat', True),
#  ('A madness of sunshine', 'Nalini Singh', 'wel', True),
#  ('A madness of sunshine', 'Nalini Singh', 'win', True),
#  ('A madness of sunshine', 'Nalini Singh', 'wlm', True),
#  ('A madness of sunshine', 'Nalini Singh', 'wob', True),
#  ('A madness of sunshine', 'Nalini Singh', 'wsn', True),
#  ('A madness of sunshine', 'Nalini Singh', 'wwd', True),
#  ('A memory called empire', 'Arkady Martine', 'act', True),
#  ('A memory called empire', 'Arkady Martine', 'arl', True),
#  ('A memory called empire', 'Arkady Martine', 'ash', True),
#  ('A memory called empire', 'Arkady Martine', 'bed', True),
#  ('A memory called empire', 'Arkady Martine', 'blm', True),
#  ('A memory called empire', 'Arkady Martine', 'br3', True),
#  ('A memory called empire', 'Arkady Martine', 'brk', True),
#  ('A memory called empire', 'Arkady Martine', 'ca5', True),
#  ('A memory called empire', 'Arkady Martine', 'cam', True),
#  ('A memory called empire', 'Arkady Martine', 'co2', True),
#  ('A memory called empire', 'Arkady Martine', 'con', True),
#  ('A memory called empire', 'Arkady Martine', 'fpl', True),
#  ('A memory called empire', 'Arkady Martine', 'lex', True),
#  ('A memory called empire', 'Arkady Martine', 'lin', True),
#  ('A memory called empire', 'Arkady Martine', 'may', True),
#  ('A memory called empire', 'Arkady Martine', 'med', True),
#  ('A memory called empire', 'Arkady Martine', 'mld', True),
#  ('A memory called empire', 'Arkady Martine', 'nat', True),
#  ('A memory called empire', 'Arkady Martine', 'nee', True),
#  ('A memory called empire', 'Arkady Martine', 'nor', True),
#  ('A memory called empire', 'Arkady Martine', 'ntn', True),
#  ('A memory called empire', 'Arkady Martine', 'oln', True),
#  ('A memory called empire', 'Arkady Martine', 'so3', True),
#  ('A memory called empire', 'Arkady Martine', 'som', True),
#  ('A memory called empire', 'Arkady Martine', 'sud', True),
#  ('A memory called empire', 'Arkady Martine', 'wat', True),
#  ('A memory called empire', 'Arkady Martine', 'wel', True),
#  ('A memory called empire', 'Arkady Martine', 'win', True),
#  ('A memory called empire', 'Arkady Martine', 'wlm', True),
#  ('A memory called empire', 'Arkady Martine', 'wob', True),
#  ('A memory called empire', 'Arkady Martine', 'wsn', True),
#  ('A memory called empire', 'Arkady Martine', 'wwd', True),
#  ('A memory called empire', 'Arkady Martine', 'wyl', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'arl', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'blm', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'ca9', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'cam', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'lex', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'nat', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'ntn', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'wob', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'wsn', True),
#  ('A mind spread out on the ground', 'Alicia Elliott', 'wyl', True),
#  ('A month in Siena', 'Hisham Matar', 'arl', True),
#  ('A month in Siena', 'Hisham Matar', 'blm', True),
#  ('A month in Siena', 'Hisham Matar', 'ca5', True),
#  ('A month in Siena', 'Hisham Matar', 'ca9', True),
#  ('A month in Siena', 'Hisham Matar', 'cam', True),
#  ('A month in Siena', 'Hisham Matar', 'con', True),
#  ('A month in Siena', 'Hisham Matar', 'fpl', True),
#  ('A month in Siena', 'Hisham Matar', 'lex', True),
#  ('A month in Siena', 'Hisham Matar', 'na2', True),
#  ('A month in Siena', 'Hisham Matar', 'nat', True),
#  ('A month in Siena', 'Hisham Matar', 'nor', True),
#  ('A month in Siena', 'Hisham Matar', 'ntn', True),
#  ('A month in Siena', 'Hisham Matar', 'som', True),
#  ('A month in Siena', 'Hisham Matar', 'wat', True),
#  ('A month in Siena', 'Hisham Matar', 'wel', True),
#  ('A month in Siena', 'Hisham Matar', 'win', True),
#  ('A month in Siena', 'Hisham Matar', 'wlm', True),
#  ('A month in Siena', 'Hisham Matar', 'wyl', True),
#  ('A nail the evening hangs on', 'Monica Sok', 'arl', True),
#  ('A nail the evening hangs on', 'Monica Sok', 'bed', True),
#  ('A nail the evening hangs on', 'Monica Sok', 'cam', True),
#  ('A nail the evening hangs on', 'Monica Sok', 'con', True),
#  ('A nail the evening hangs on', 'Monica Sok', 'ntn', True),
#  ('A nail the evening hangs on', 'Monica Sok', 'wel', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'arl', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'ash', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'bed', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'blm', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'brk', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'ca9', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'cam', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'fpl', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'frk', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'lex', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'lin', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'may', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'med', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'mwy', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'nee', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'nor', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'ntn', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'som', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'sud', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'wat', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'wel', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'wlm', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'wsn', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'wwd', True),
#  ('A particular kind of Black man', 'Tope Folarin', 'wyl', True),
#  ('A prince on paper', 'Alyssa Cole', 'ar2', True),
#  ('A prince on paper', 'Alyssa Cole', 'arl', True),
#  ('A prince on paper', 'Alyssa Cole', 'ash', True),
#  ('A prince on paper', 'Alyssa Cole', 'blm', True),
#  ('A prince on paper', 'Alyssa Cole', 'brk', True),
#  ('A prince on paper', 'Alyssa Cole', 'cam', True),
#  ('A prince on paper', 'Alyssa Cole', 'fpl', True),
#  ('A prince on paper', 'Alyssa Cole', 'frk', True),
#  ('A prince on paper', 'Alyssa Cole', 'lex', True),
#  ('A prince on paper', 'Alyssa Cole', 'med', True),
#  ('A prince on paper', 'Alyssa Cole', 'mwy', True),
#  ('A prince on paper', 'Alyssa Cole', 'nee', True),
#  ('A prince on paper', 'Alyssa Cole', 'ntn', True),
#  ('A prince on paper', 'Alyssa Cole', 'som', True),
#  ('A prince on paper', 'Alyssa Cole', 'wat', True),
#  ('A prince on paper', 'Alyssa Cole', 'wlm', True),
#  ('A prince on paper', 'Alyssa Cole', 'wsn', True),
#  ('A prince on paper', 'Alyssa Cole', 'wwd', True),
#  ('A prince on paper', 'Alyssa Cole', 'wyl', True),
#  ('A princess in theory', 'Alyssa Cole', 'act', True),
#  ('A princess in theory', 'Alyssa Cole', 'ar2', True),
#  ('A princess in theory', 'Alyssa Cole', 'arl', True),
#  ('A princess in theory', 'Alyssa Cole', 'ash', True),
#  ('A princess in theory', 'Alyssa Cole', 'blm', True),
#  ('A princess in theory', 'Alyssa Cole', 'br2', True),
#  ('A princess in theory', 'Alyssa Cole', 'brk', True),
#  ('A princess in theory', 'Alyssa Cole', 'ca9', True),
#  ('A princess in theory', 'Alyssa Cole', 'cam', True),
#  ('A princess in theory', 'Alyssa Cole', 'frk', True),
#  ('A princess in theory', 'Alyssa Cole', 'lex', True),
#  ('A princess in theory', 'Alyssa Cole', 'may', True),
#  ('A princess in theory', 'Alyssa Cole', 'mwy', True),
#  ('A princess in theory', 'Alyssa Cole', 'nat', True),
#  ('A princess in theory', 'Alyssa Cole', 'nee', True),
#  ('A princess in theory', 'Alyssa Cole', 'ntn', True),
#  ('A princess in theory', 'Alyssa Cole', 'so3', True),
#  ('A princess in theory', 'Alyssa Cole', 'som', True),
#  ('A princess in theory', 'Alyssa Cole', 'wat', True),
#  ('A princess in theory', 'Alyssa Cole', 'wwd', True),
#  ('A princess in theory', 'Alyssa Cole', 'wyl', True),
#  ('A room called earth', 'Madeleine Ryan', 'arl', True),
#  ('A room called earth', 'Madeleine Ryan', 'ash', True),
#  ('A room called earth', 'Madeleine Ryan', 'bed', True),
#  ('A room called earth', 'Madeleine Ryan', 'brk', True),
#  ('A room called earth', 'Madeleine Ryan', 'ca9', True),
#  ('A room called earth', 'Madeleine Ryan', 'cam', True),
#  ('A room called earth', 'Madeleine Ryan', 'con', True),
#  ('A room called earth', 'Madeleine Ryan', 'dd2', True),
#  ('A room called earth', 'Madeleine Ryan', 'ddm', True),
#  ('A room called earth', 'Madeleine Ryan', 'lex', True),
#  ('A room called earth', 'Madeleine Ryan', 'med', True),
#  ('A room called earth', 'Madeleine Ryan', 'nat', True),
#  ('A room called earth', 'Madeleine Ryan', 'nee', True),
#  ('A room called earth', 'Madeleine Ryan', 'nor', True),
#  ('A room called earth', 'Madeleine Ryan', 'ntn', True),
#  ('A room called earth', 'Madeleine Ryan', 'som', True),
#  ('A room called earth', 'Madeleine Ryan', 'sud', True),
#  ('A room called earth', 'Madeleine Ryan', 'wat', True),
#  ('A room called earth', 'Madeleine Ryan', 'wel', True),
#  ('A room called earth', 'Madeleine Ryan', 'win', True),
#  ('A room called earth', 'Madeleine Ryan', 'wob', True),
#  ('A room called earth', 'Madeleine Ryan', 'wsn', True),
#  ('A spy in the struggle', 'Aya De León', 'arl', True),
#  ('A spy in the struggle', 'Aya De León', 'brk', True),
#  ('A spy in the struggle', 'Aya De León', 'cam', True),
#  ('A spy in the struggle', 'Aya De León', 'fpl', True),
#  ('A spy in the struggle', 'Aya De León', 'lex', True),
#  ('A spy in the struggle', 'Aya De León', 'nee', True),
#  ('A spy in the struggle', 'Aya De León', 'som', True),
#  ('A spy in the struggle', 'Aya De León', 'wat', True),
#  ('A spy in the struggle', 'Aya De León', 'wlm', True),
#  ('A sweet mess', 'Jayci Lee', 'arl', True),
#  ('A sweet mess', 'Jayci Lee', 'ash', True),
#  ('A sweet mess', 'Jayci Lee', 'br2', True),
#  ('A sweet mess', 'Jayci Lee', 'brk', True),
#  ('A sweet mess', 'Jayci Lee', 'nat', True),
#  ('A sweet mess', 'Jayci Lee', 'nee', True),
#  ('A sweet mess', 'Jayci Lee', 'win', True),
#  ('A sweet mess', 'Jayci Lee', 'wob', True),
#  ('A sweet mess', 'Jayci Lee', 'wwd', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'act', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'arl', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'bed', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'blm', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'cam', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'con', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'fpl', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'frk', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'lex', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'may', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'med', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'mwy', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'nee', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'nor', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'ntn', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'som', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'sud', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'wat', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'wel', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'win', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'wlm', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'wsn', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'wwd', True),
#  ('A tall history of sugar', 'Curdella Forbes', 'wyl', True),
#  ('A thousand times you lose your treasure', 'Hoa Nguyen', 'cam', True),
#  ('A tiny piece of something greater', 'Jude Sierra', 'las', True),
#  ('A treatise on stars', 'Mei-mei Berssenbrugge', 'nor', True),
#  ('A treatise on stars', 'Mei-mei Berssenbrugge', 'ntn', True),
#  ('Accidentally engaged', 'Farah Heron', 'act', True),
#  ('Accidentally engaged', 'Farah Heron', 'arl', True),
#  ('Accidentally engaged', 'Farah Heron', 'ash', True),
#  ('Accidentally engaged', 'Farah Heron', 'blm', True),
#  ('Accidentally engaged', 'Farah Heron', 'br2', True),
#  ('Accidentally engaged', 'Farah Heron', 'br3', True),
#  ('Accidentally engaged', 'Farah Heron', 'brk', True),
#  ('Accidentally engaged', 'Farah Heron', 'ca5', True),
#  ('Accidentally engaged', 'Farah Heron', 'cam', True),
#  ('Accidentally engaged', 'Farah Heron', 'con', True),
#  ('Accidentally engaged', 'Farah Heron', 'fp2', True),
#  ('Accidentally engaged', 'Farah Heron', 'fpl', True),
#  ('Accidentally engaged', 'Farah Heron', 'lex', True),
#  ('Accidentally engaged', 'Farah Heron', 'nat', True),
#  ('Accidentally engaged', 'Farah Heron', 'nee', True),
#  ('Accidentally engaged', 'Farah Heron', 'ntn', True),
#  ('Accidentally engaged', 'Farah Heron', 'som', True),
#  ('Accidentally engaged', 'Farah Heron', 'wat', True),
#  ('Accidentally engaged', 'Farah Heron', 'win', True),
#  ('Accidentally engaged', 'Farah Heron', 'wsn', True),
#  ('After hours redemption', 'Kianna Alexander', 'cam', True),
#  ('After she wrote him', 'Sulari Gentill', 'ash', True),
#  ('After she wrote him', 'Sulari Gentill', 'cam', True),
#  ('After she wrote him', 'Sulari Gentill', 'lin', True),
#  ('After she wrote him', 'Sulari Gentill', 'may', True),
#  ('After she wrote him', 'Sulari Gentill', 'med', True),
#  ('After she wrote him', 'Sulari Gentill', 'ntn', True),
#  ('After she wrote him', 'Sulari Gentill', 'win', True),
#  ('After the dragons', 'Cynthia Zhang', 'brk', True),
#  ('After the dragons', 'Cynthia Zhang', 'wat', True),
#  ('After the dragons', 'Cynthia Zhang', 'wyl', True),
#  ('After the eclipse', 'Fran Dorricott', 'ddm', True),
#  ('After the eclipse', 'Fran Dorricott', 'frk', True),
#  ('After the eclipse', 'Fran Dorricott', 'ntn', True),
#  ('After the eclipse', 'Fran Dorricott', 'wat', True),
#  ('After the eclipse', 'Fran Dorricott', 'wlm', True),
#  ('After the wedding', 'Courtney Milan', 'blm', True),
#  ('After the wedding', 'Courtney Milan', 'lex', True),
#  ('After the wedding', 'Courtney Milan', 'med', True),
#  ('After the wedding', 'Courtney Milan', 'nee', True),
#  ('After the winter', 'Guadalupe Nettel', 'brk', True),
#  ('After the winter', 'Guadalupe Nettel', 'cam', True),
#  ('After the winter', 'Guadalupe Nettel', 'lex', True),
#  ('After the winter', 'Guadalupe Nettel', 'med', True),
#  ('After the winter', 'Guadalupe Nettel', 'ntn', True),
#  ('After the winter', 'Guadalupe Nettel', 'sud', True),
#  ('After the winter', 'Guadalupe Nettel', 'wlm', True),
#  ('After the winter', 'Guadalupe Nettel', 'wyl', True),
#  ('Alibis & angels', 'Olivia Matthews', 'bed', True),
#  ('Alibis & angels', 'Olivia Matthews', 'blm', True),
#  ('Alibis & angels', 'Olivia Matthews', 'fpl', True),
#  ('Alibis & angels', 'Olivia Matthews', 'med', True),
#  ('Alienation', 'Inés Estrada', 'arl', True),
#  ('Alienation', 'Inés Estrada', 'blm', True),
#  ('Alienation', 'Inés Estrada', 'ca5', True),
#  ('Alienation', 'Inés Estrada', 'may', True),
#  ('Alienation', 'Inés Estrada', 'med', True),
#  ('Alienation', 'Inés Estrada', 'som', True),
#  ('All my goodbyes', 'Mariana Dimópulos', 'bed', True),
#  ('All my goodbyes', 'Mariana Dimópulos', 'cam', True),
#  ('All my goodbyes', 'Mariana Dimópulos', 'lex', True),
#  ('All my goodbyes', 'Mariana Dimópulos', 'ntn', True),
#  ('All my goodbyes', 'Mariana Dimópulos', 'sud', True),
#  ('All my goodbyes', 'Mariana Dimópulos', 'wat', True),
#  ('All my goodbyes', 'Mariana Dimópulos', 'win', True),
#  ('All my goodbyes', 'Mariana Dimópulos', 'wlm', True),
#  ('All my goodbyes', 'Mariana Dimópulos', 'wyl', True),
#  ('All my lies are true', 'Dorothy Koomson', 'bed', True),
#  ('All my lies are true', 'Dorothy Koomson', 'cam', True),
#  ('All my lies are true', 'Dorothy Koomson', 'may', True),
#  ('All my lies are true', 'Dorothy Koomson', 'ntn', True),
#  ('All my lies are true', 'Dorothy Koomson', 'wat', True),
#  ('All my lies are true', 'Dorothy Koomson', 'wlm', True),
#  ('All the Gay Saints', 'Kayleb Rae Candrilli', 'ntn', True),
#  ('All the lonely people', 'Mike Gayle', 'blm', True),
#  ('All the lonely people', 'Mike Gayle', 'brk', True),
#  ('All the lonely people', 'Mike Gayle', 'cam', True),
#  ('All the lonely people', 'Mike Gayle', 'lex', True),
#  ('All the lonely people', 'Mike Gayle', 'med', True),
#  ('All the lonely people', 'Mike Gayle', 'mld', True),
#  ('All the lonely people', 'Mike Gayle', 'nat', True),
#  ('All the lonely people', 'Mike Gayle', 'ntn', True),
#  ('All the lonely people', 'Mike Gayle', 'sud', True),
#  ('All the lonely people', 'Mike Gayle', 'wat', True),
#  ('All the lonely people', 'Mike Gayle', 'wlm', True),
#  ('Alpha night', 'Nalini Singh', 'arl', True),
#  ('Alpha night', 'Nalini Singh', 'br2', True),
#  ('Alpha night', 'Nalini Singh', 'brk', True),
#  ('Alpha night', 'Nalini Singh', 'cam', True),
#  ('Alpha night', 'Nalini Singh', 'lex', True),
#  ('Alpha night', 'Nalini Singh', 'nat', True),
#  ('Alpha night', 'Nalini Singh', 'nee', True),
#  ('Alpha night', 'Nalini Singh', 'nor', True),
#  ('Alpha night', 'Nalini Singh', 'ntn', True),
#  ('Alpha night', 'Nalini Singh', 'som', True),
#  ('America for beginners', 'Leah Franqui', 'ac2', True),
#  ('America for beginners', 'Leah Franqui', 'act', True),
#  ('America for beginners', 'Leah Franqui', 'arl', True),
#  ('America for beginners', 'Leah Franqui', 'ash', True),
#  ('America for beginners', 'Leah Franqui', 'brk', True),
#  ('America for beginners', 'Leah Franqui', 'ca5', True),
#  ('America for beginners', 'Leah Franqui', 'ca9', True),
#  ('America for beginners', 'Leah Franqui', 'cam', True),
#  ('America for beginners', 'Leah Franqui', 'con', True),
#  ('America for beginners', 'Leah Franqui', 'fpl', True),
#  ('America for beginners', 'Leah Franqui', 'frk', True),
#  ('America for beginners', 'Leah Franqui', 'hol', True),
#  ('America for beginners', 'Leah Franqui', 'lex', True),
#  ('America for beginners', 'Leah Franqui', 'lin', True),
#  ('America for beginners', 'Leah Franqui', 'may', True),
#  ('America for beginners', 'Leah Franqui', 'med', True),
#  ('America for beginners', 'Leah Franqui', 'nat', True),
#  ('America for beginners', 'Leah Franqui', 'nee', True),
#  ('America for beginners', 'Leah Franqui', 'nor', True),
#  ('America for beginners', 'Leah Franqui', 'ntn', True),
#  ('America for beginners', 'Leah Franqui', 'so3', True),
#  ('America for beginners', 'Leah Franqui', 'som', True),
#  ('America for beginners', 'Leah Franqui', 'sud', True),
#  ('America for beginners', 'Leah Franqui', 'wat', True),
#  ('America for beginners', 'Leah Franqui', 'wel', True),
#  ('America for beginners', 'Leah Franqui', 'win', True),
#  ('America for beginners', 'Leah Franqui', 'wlm', True),
#  ('America for beginners', 'Leah Franqui', 'wwd', True),
#  ('America for beginners', 'Leah Franqui', 'wyl', True),
#  ('America is not the heart', 'Elaine Castillo', 'act', True),
#  ('America is not the heart', 'Elaine Castillo', 'arl', True),
#  ('America is not the heart', 'Elaine Castillo', 'ash', True),
#  ('America is not the heart', 'Elaine Castillo', 'bed', True),
#  ('America is not the heart', 'Elaine Castillo', 'blm', True),
#  ('America is not the heart', 'Elaine Castillo', 'brk', True),
#  ('America is not the heart', 'Elaine Castillo', 'ca4', True),
#  ('America is not the heart', 'Elaine Castillo', 'ca5', True),
#  ('America is not the heart', 'Elaine Castillo', 'ca6', True),
#  ('America is not the heart', 'Elaine Castillo', 'ca8', True),
#  ('America is not the heart', 'Elaine Castillo', 'cam', True),
#  ('America is not the heart', 'Elaine Castillo', 'co2', True),
#  ('America is not the heart', 'Elaine Castillo', 'con', True),
#  ('America is not the heart', 'Elaine Castillo', 'fpl', True),
#  ('America is not the heart', 'Elaine Castillo', 'frk', True),
#  ('America is not the heart', 'Elaine Castillo', 'lex', True),
#  ('America is not the heart', 'Elaine Castillo', 'lin', True),
#  ('America is not the heart', 'Elaine Castillo', 'may', True),
#  ('America is not the heart', 'Elaine Castillo', 'med', True),
#  ('America is not the heart', 'Elaine Castillo', 'nat', True),
#  ('America is not the heart', 'Elaine Castillo', 'nee', True),
#  ('America is not the heart', 'Elaine Castillo', 'ntn', True),
#  ('America is not the heart', 'Elaine Castillo', 'shr', True),
#  ('America is not the heart', 'Elaine Castillo', 'som', True),
#  ('America is not the heart', 'Elaine Castillo', 'sud', True),
#  ('America is not the heart', 'Elaine Castillo', 'wat', True),
#  ('America is not the heart', 'Elaine Castillo', 'wel', True),
#  ('America is not the heart', 'Elaine Castillo', 'win', True),
#  ('America is not the heart', 'Elaine Castillo', 'wlm', True),
#  ('America is not the heart', 'Elaine Castillo', 'wob', True),
#  ('America is not the heart', 'Elaine Castillo', 'wwd', True),
#  ('America is not the heart', 'Elaine Castillo', 'wyl', True),
#  ('American Fairytale', 'Adriana Herrera', 'wat', True),
#  ('American dreamer', 'Adriana Herrera', 'br3', True),
#  ('American dreamer', 'Adriana Herrera', 'brk', True),
#  ('American dreamer', 'Adriana Herrera', 'frk', True),
#  ('American dreamer', 'Adriana Herrera', 'lex', True),
#  ('American dreamer', 'Adriana Herrera', 'med', True),
#  ('American dreamer', 'Adriana Herrera', 'nee', True),
#  ('American dreamer', 'Adriana Herrera', 'wlm', True),
#  ('American fairytale', 'Adriana Herrera', 'frk', True),
#  ('American fairytale', 'Adriana Herrera', 'lex', True),
#  ('American fairytale', 'Adriana Herrera', 'med', True),
#  ('American fairytale', 'Adriana Herrera', 'nee', True),
#  ('American fairytale', 'Adriana Herrera', 'wyl', True),
#  ('American love story', 'Adriana Herrera', 'brk', True),
#  ('American love story', 'Adriana Herrera', 'frk', True),
#  ('American love story', 'Adriana Herrera', 'lex', True),
#  ('American love story', 'Adriana Herrera', 'nee', True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'arl',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'bed',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'blm',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'brk',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'ca9',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'cam',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'con',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'fpl',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'frk',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'lex',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'lin',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'med',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'nat',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'nor',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'ntn',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'sud',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'wat',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'wel',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'wlm',
#   True),
#  ('American sonnets for my past and future assassin',
#   'Terrance Hayes',
#   'wyl',
#   True),
#  ('American sweethearts', 'Adriana Herrera', 'bed', True),
#  ('American sweethearts', 'Adriana Herrera', 'blm', True),
#  ('American sweethearts', 'Adriana Herrera', 'brk', True),
#  ('American sweethearts', 'Adriana Herrera', 'cam', True),
#  ('American sweethearts', 'Adriana Herrera', 'frk', True),
#  ('American sweethearts', 'Adriana Herrera', 'lex', True),
#  ('American sweethearts', 'Adriana Herrera', 'med', True),
#  ('American sweethearts', 'Adriana Herrera', 'nat', True),
#  ('American sweethearts', 'Adriana Herrera', 'wlm', True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'arl',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'bed',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'blm',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'brk',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'ca9',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'cam',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'con',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'dov',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'fpl',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'lex',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'med',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'nee',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'nor',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'ntn',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'pmc',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'som',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'sto',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'sud',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'wat',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'wel',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'win',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'wlm',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'wob',
#   True),
#  ('An African American and Latinx history of the United States',
#   'Paul Ortiz',
#   'wsn',
#   True),
#  ('An I-novel', 'Minae Mizumura', 'bed', True),
#  ('An I-novel', 'Minae Mizumura', 'blm', True),
#  ('An I-novel', 'Minae Mizumura', 'cam', True),
#  ('An I-novel', 'Minae Mizumura', 'mld', True),
#  ('An I-novel', 'Minae Mizumura', 'ntn', True),
#  ('An acquired taste', 'Kelly Cain', 'wlm', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'arl', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'ash', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'blm', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'brk', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'ca5', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'ca8', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'cam', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'frk', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'lex', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'nat', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'nee', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'nor', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'ntn', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'som', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'wat', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'wlm', True),
#  ('An earl, the girl, and a toddler', 'Vanessa Riley', 'wwd', True),
#  ('An ocean of minutes', 'Thea Lim', 'act', True),
#  ('An ocean of minutes', 'Thea Lim', 'arl', True),
#  ('An ocean of minutes', 'Thea Lim', 'blm', True),
#  ('An ocean of minutes', 'Thea Lim', 'brk', True),
#  ('An ocean of minutes', 'Thea Lim', 'ca5', True),
#  ('An ocean of minutes', 'Thea Lim', 'cam', True),
#  ('An ocean of minutes', 'Thea Lim', 'con', True),
#  ('An ocean of minutes', 'Thea Lim', 'fpl', True),
#  ('An ocean of minutes', 'Thea Lim', 'lex', True),
#  ('An ocean of minutes', 'Thea Lim', 'lin', True),
#  ('An ocean of minutes', 'Thea Lim', 'may', True),
#  ('An ocean of minutes', 'Thea Lim', 'med', True),
#  ('An ocean of minutes', 'Thea Lim', 'nat', True),
#  ('An ocean of minutes', 'Thea Lim', 'nee', True),
#  ('An ocean of minutes', 'Thea Lim', 'nor', True),
#  ('An ocean of minutes', 'Thea Lim', 'ntn', True),
#  ('An ocean of minutes', 'Thea Lim', 'sud', True),
#  ('An ocean of minutes', 'Thea Lim', 'wel', True),
#  ('An ocean of minutes', 'Thea Lim', 'win', True),
#  ('An ocean of minutes', 'Thea Lim', 'wlm', True),
#  ('An ocean of minutes', 'Thea Lim', 'wob', True),
#  ('An ocean of minutes', 'Thea Lim', 'ww2', True),
#  ('An ocean of minutes', 'Thea Lim', 'wwd', True),
#  ('An ocean of minutes', 'Thea Lim', 'wyl', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'arl', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'ash', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'bed', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'blm', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'brk', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'ca9', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'cam', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'frk', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'lex', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'med', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'nee', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'ntn', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'wlm', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'wsn', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'wwd', True),
#  ('An unconditional freedom', 'Alyssa Cole', 'wyl', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'arl', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'ash', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'blm', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'br2', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'brk', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'cam', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'frk', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'lex', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'nee', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'nor', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'ntn', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'wat', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'win', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'wlm', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'wob', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'wsn', True),
#  ('Anchored hearts', 'Priscilla Oliveras', 'wyl', True),
#  ('Angel bones', 'Ilyse Kusnetz', 'cam', True),
#  ('Angel bones', 'Ilyse Kusnetz', 'wlm', True),
#  ('Anodyne', 'Khadijah Queen', 'cam', True),
#  ('Anodyne', 'Khadijah Queen', 'ddm', True),
#  ('Anodyne', 'Khadijah Queen', 'lex', True),
#  ('Anodyne', 'Khadijah Queen', 'ntn', True),
#  ('Apsara engine', 'Bishakh Som', 'arl', True),
#  ('Apsara engine', 'Bishakh Som', 'bed', True),
#  ('Apsara engine', 'Bishakh Som', 'cam', True),
#  ('Apsara engine', 'Bishakh Som', 'con', True),
#  ('Apsara engine', 'Bishakh Som', 'mld', True),
#  ('Apsara engine', 'Bishakh Som', 'ntn', True),
#  ('Apsara engine', 'Bishakh Som', 'som', True),
#  ('Apsara engine', 'Bishakh Som', 'wat', True),
#  ('Apsara engine', 'Bishakh Som', 'wel', True),
#  ('Apsara engine', 'Bishakh Som', 'win', True),
#  ('Apsara engine', 'Bishakh Som', 'wlm', True),
#  ('Apsara engine', 'Bishakh Som', 'wyl', True),
#  ('Aria', 'Nazanine Hozar', 'arl', True),
#  ('Aria', 'Nazanine Hozar', 'bed', True),
#  ('Aria', 'Nazanine Hozar', 'blm', True),
#  ('Aria', 'Nazanine Hozar', 'brk', True),
#  ('Aria', 'Nazanine Hozar', 'ca4', True),
#  ('Aria', 'Nazanine Hozar', 'ca9', True),
#  ('Aria', 'Nazanine Hozar', 'cam', True),
#  ('Aria', 'Nazanine Hozar', 'con', True),
#  ('Aria', 'Nazanine Hozar', 'fp2', True),
#  ('Aria', 'Nazanine Hozar', 'fpl', True),
#  ('Aria', 'Nazanine Hozar', 'lex', True),
#  ('Aria', 'Nazanine Hozar', 'lin', True),
#  ('Aria', 'Nazanine Hozar', 'med', True),
#  ('Aria', 'Nazanine Hozar', 'nat', True),
#  ('Aria', 'Nazanine Hozar', 'nee', True),
#  ('Aria', 'Nazanine Hozar', 'nor', True),
#  ('Aria', 'Nazanine Hozar', 'ntn', True),
#  ('Aria', 'Nazanine Hozar', 'som', True),
#  ('Aria', 'Nazanine Hozar', 'sto', True),
#  ('Aria', 'Nazanine Hozar', 'wat', True),
#  ('Aria', 'Nazanine Hozar', 'wob', True),
#  ('Aria', 'Nazanine Hozar', 'wsn', True),
#  ('Aria', 'Nazanine Hozar', 'wwd', True),
#  ('Aria', 'Nazanine Hozar', 'wyl', True),
#  ('Assembly', 'Natasha Brown', 'blm', True),
#  ('Assembly', 'Natasha Brown', 'con', True),
#  ('Assembly', 'Natasha Brown', 'nee', True),
#  ('Assembly', 'Natasha Brown', 'wat', True),
#  ('Assembly', 'Natasha Brown', 'wlm', True),
#  ('At night all blood is black', 'David Diop', 'act', True),
#  ('At night all blood is black', 'David Diop', 'arl', True),
#  ('At night all blood is black', 'David Diop', 'bed', True),
#  ('At night all blood is black', 'David Diop', 'blm', True),
#  ('At night all blood is black', 'David Diop', 'brk', True),
#  ('At night all blood is black', 'David Diop', 'ca7', True),
#  ('At night all blood is black', 'David Diop', 'ca9', True),
#  ('At night all blood is black', 'David Diop', 'cam', True),
#  ('At night all blood is black', 'David Diop', 'fpl', True),
#  ('At night all blood is black', 'David Diop', 'hol', True),
#  ('At night all blood is black', 'David Diop', 'lex', True),
#  ('At night all blood is black', 'David Diop', 'med', True),
#  ('At night all blood is black', 'David Diop', 'nee', True),
#  ('At night all blood is black', 'David Diop', 'ntn', True),
#  ('At night all blood is black', 'David Diop', 'wat', True),
#  ('At night all blood is black', 'David Diop', 'wel', True),
#  ('At night all blood is black', 'David Diop', 'win', True),
#  ('At night all blood is black', 'David Diop', 'wlm', True),
#  ('At night all blood is black', 'David Diop', 'wob', True),
#  ('At night all blood is black', 'David Diop', 'wsn', True),
#  ('At night all blood is black', 'David Diop', 'wyl', True),
#  ('August Snow', 'Stephen Mack Jones', 'med', True),
#  ('August Snow', 'Stephen Mack Jones', 'ntn', True),
#  ('Autonomous', 'Annalee Newitz', 'oln', True),
#  ('Ayesha at last', 'Uzma Jalaluddin', 'ar2', True),
#  ('Ayesha at last', 'Uzma Jalaluddin', 'arl', True),
#  ('Ayesha at last', 'Uzma Jalaluddin', 'ash', True),
#  ('Ayesha at last', 'Uzma Jalaluddin', 'bed', True),
#  ...]
